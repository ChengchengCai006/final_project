# %% [markdown]
# # NYC Apartment Search
#
# _[Project prompt](https://docs.google.com/document/d/1uAUJGEUzfNj6OsWNAimnYCw7eKaHhMUfU1MTj9YwYw4/edit?usp=sharing), [grading rubric](https://docs.google.com/document/d/1UYkYtDtHJS2nzodDjJ3X3c2AdYNuj3ueki58p_hQGhA/edit)_
#
#
# **Background:**
#
# Imagine your apartment lease is ending at the close of the year, and the search for a new apartment is on. To narrow down potential neighborhoods, you've identified key criteria that matter to you.
#
# **Goals:**
#
# - quiet neighborhood (relating to dataset of `311 complaints`)
# - a lot of greenery (relating to dataset of `2015 tree census`)
# - within budget (relating to dataset of `Zillow`)

# %% [markdown]
# ## Setup

# %%
# All import statements needed for the project
import pathlib
import pandas as pd
import geopandas as gpd
from geopandas import GeoDataFrame
import matplotlib.pyplot as plt
import requests
import re
import psycopg2
import shapely
import folium

from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String, Float, TIMESTAMP, Date, text
from geoalchemy2 import Geometry, WKTElement
from datetime import datetime, timedelta
from shapely.geometry import Point
from shapely.wkb import dumps
from pathlib import Path
from geopy.distance import geodesic
from ipywidgets import IntSlider, interact, fixed

# %%
# Any constants you might need; some have been added for you

## File Path
DATA_DIR = pathlib.Path("data")
ZIPCODE_DATA_FILE = DATA_DIR / "nyc_zipcodes.shp"
ZILLOW_DATA_FILE = DATA_DIR / "zillow_rent_data.csv"

## Application token and json url for downloading nyc_311 and nyc_tree
NYC_DATA_APP_TOKEN = "NJflFVV2YiwlXmMlt4Y9jwTGO"
API_311 = 'https://data.cityofnewyork.us/resource/erm2-nwe9.json'
API_TREE='https://data.cityofnewyork.us/resource/uvpi-gqnh.json'

## Soql for NYC_311 and NYC_TREE Download
SOQL_BASE_QUERY_311 = f"{API_311}?$where=created_date between '2015-01-01T00:00:00' and '2023-10-31T00:00:00'&$limit=1000000"
SOQL_QUERIES_311 = {f"query_{i}": f"{SOQL_BASE_QUERY_311}&$offset={(i-1)*1000000}" for i in range(1, 26)}
SOQL_QUERY_TREE=f"{API_TREE}?$where=created_at between '2015-01-01T00:00:00' and '2015-12-31T23:59:59'&$limit=1000000000"

## Postgresql Database information
DB_NAME = "GroupProject"
DB_USER = 'postgres'
DB_PASSWORD = ''
DB_HOST = 'localhost'
DB_URL=f'postgresql://{DB_USER}:{DB_PASSWORD}@{DB_HOST}/{DB_NAME}'

## Database schema file
DB_SCHEMA_FILE = "schema.sql"

## campus geometry information
latitude = 40.80737875669467
longitude = -73.96253174434912
point = Point(longitude, latitude)
point_wkt = f"POINT({longitude} {latitude})"
point_wkb = dumps(point, hex=True)

## directory where DB queries for Part 3 will be saved
QUERY_DIR = pathlib.Path("queries")

# %%
# Make sure the QUERY_DIRECTORY exists
if not QUERY_DIR.exists():
    QUERY_DIR.mkdir()

# %% [markdown]
# ## Part 1: Data Preprocessing
#
# In Part 1, we processed four datasets: **NYC311**, **NYCTree**, **NYC Zipcode**, and **NYC Zillow**.

# %% [markdown]
# ### 1. Download and Clean NYC_311
# - **Download:**
#   - Implemented a function `download_nyc_json_data` using application tokens and API URLs to retrieve JSON data, converting it to a DataFrame.
#   - Executed `download_311_data` to handle the large dataset. It utilized SOQL queries to download 1 million records at a time, repeating this 25 times. Each batch was saved as a CSV file to manage the dataset's size efficiently.
#
# - **Clean:**
#   - Implemented function `load_and_clean_311_data`
#       - read and concatenate all saved CSV files into a single DataFrame.
#       - Selected columns (`unique_key`, `created_date`, `complaint_type`, `incident_zip`, `latitude`, `longitude`) and created a new 'location' column using GeoPandas for spatial data representation.
#       - Dropped the original `latitude` and `longitude` columns and renamed `incident_zip` to `zipcode`.
#       - Removed rows with missing zip codes and converted the data types of columns (`unique_key`, `created_date`, `complaint_type`, `zipcode`) for consistency and accuracy.
#       - Transformed the DataFrame into a GeoDataFrame with 'location' as the geometry column for spatial analysis.

# %%
# this function is used to download json url using application token
def download_nyc_json_data(query: str) -> pd.DataFrame:
    headers = {'X-App-Token': NYC_DATA_APP_TOKEN }
    response = requests.get(query, headers=headers)
    df = pd.read_json(response.text)
    return df

# %%
# this function is used download nyc_311 data
def download_311_data(queries_dict: dict):
    for query_name, query in queries_dict.items():
        query_df = download_nyc_json_data(query)
        query_df.to_csv(f"{query_name}_data.csv", index=False)

# %%
# this function is used to load and clean 311 data
def load_and_clean_311_data() -> GeoDataFrame:
    ## read and concat all 311 data, which previously saved as csv file
    all_data = pd.concat([pd.read_csv(f"{query_name}_data.csv", low_memory=False) for query_name in SOQL_QUERIES_311], ignore_index=True)
    
    ## choose columns which will be used for later analysis
    data_311 = all_data[['unique_key', 'created_date', 'complaint_type', 'incident_zip', 'latitude', 'longitude']].copy()

    # Create a new column 'location' without modifying the original DataFrame
    data_311['location'] = gpd.points_from_xy(data_311['longitude'], data_311['latitude'], crs="EPSG:4326")

    # Drop latitude and longitude columns
    data_311 = data_311.drop(['latitude', 'longitude'], axis=1)

    # Rename columns
    data_311 = data_311.rename(columns={"incident_zip": "zipcode"})

    # Drop rows with missing zip codes
    data_311['zipcode'] = pd.to_numeric(data_311['zipcode'], errors='coerce')
    data_311 = data_311.dropna(subset=['zipcode'])

    # Change data types
    convert_dict = {'unique_key': int, 'created_date': 'datetime64[ns]', 'complaint_type': str, 'zipcode': int}
    data_311 = data_311.astype(convert_dict)

    # Create GeoDataFrame with 'location' as the geometry column
    geo_data_311 = gpd.GeoDataFrame(data_311, geometry='location')

    return geo_data_311

# %% [markdown]
# ### 2. Download and Clean NYC_tree
# - **Download:**
#   - Utilized the `download_nyc_json_data` function with application tokens, API URLs, and a SOQL query specifically designed to retrieve tree data for the year 2015.
#
# - **Clean:**
#   - Selected relevant columns: `tree_id`, `status`, `health`, `spc_common` (species), `zipcode`, `latitude`, and `longitude`.
#   - Transformed latitude and longitude data into a GeoDataFrame with a 'location' column using GeoPandas, representing each tree's spatial data.
#   - Dropped the original `latitude` and `longitude` columns for data efficiency.
#   - Renamed the column `spc_common` to `species` for clarity and consistency.

# %%
# this function is used to load and clean tree data
def download_and_clean_tree_data() -> GeoDataFrame:
    # Download tree data for the year 2015
    tree_data = download_nyc_json_data(SOQL_QUERY_TREE)

    # Select relevant columns
    selected_columns = ['tree_id', 'status', 'health', 'spc_common', 'zipcode', 'latitude', 'longitude']
    tree_data = tree_data[selected_columns]

    # Convert latitude and longitude to a GeoDataFrame with a 'location' column
    tree_data['location'] = gpd.points_from_xy(tree_data['longitude'], tree_data['latitude'], crs="EPSG:4326")

    # Drop latitude and longitude columns
    tree_data = tree_data.drop(['latitude', 'longitude'], axis=1)

    # Rename columns
    tree_data = tree_data.rename(columns={"spc_common": "species"})

    return gpd.GeoDataFrame(tree_data, geometry='location')

# %% [markdown]
# ### 3. Load and Clean NYC_Zipcode
#
# - **Load:**
#   - Imported zipcode data using GeoPandas’ `read_file` function, with error handling to catch and report any issues during the import process.
#
# - **Clean:**
#   - Selected only the necessary columns: `ZIPCODE` and `geometry`, and renamed them to `zipcode` and `location` for clarity.
#   - Converted the data into a GeoDataFrame, setting `location` as the geometry column.
#   - Updated the coordinate reference system to `EPSG:4326` for consistent spatial data representation.
#   - Changed the data type of `zipcode` to integer for accurate data handling.
#   - Eliminated duplicate entries in the `zipcode` column to ensure data uniqueness and integrity.

# %%
# this function is used to load and clean zipcode data
def load_and_clean_zipcodes_data(zipcode_datafile: Path) -> GeoDataFrame or None: 
    try:
        data = gpd.read_file(zipcode_datafile)
        
        # Select relevant columns and rename them
        data_nyc = data[['ZIPCODE', 'geometry']].rename(
            columns={"ZIPCODE": "zipcode", "geometry": "location"})
        
        # Create GeoDataFrame with the selected and renamed columns
        zipcode_nyc = gpd.GeoDataFrame(data_nyc, geometry='location')
        
        # Change data types and coordinate reference system
        zipcode_nyc = zipcode_nyc.to_crs(epsg=4326)
        zipcode_nyc = zipcode_nyc.astype({'zipcode': int})
        
        # Drop duplicate zipcodes, keeping the first occurrence
        zipcode_nyc = zipcode_nyc.drop_duplicates(subset=['zipcode'])
        
        return zipcode_nyc
    
    except Exception as e:
        print(f"Error: {e}. Could not read file: {zipcode_datafile}")
        return None

# %% [markdown]
# ### 4. Load and Clean NYC_Zillow
#
# - **Load:**
#   - Utilized Pandas to read the Zillow dataset from a specified CSV file (`zillow_datafile`).
#
# - **Clean:**
#   - Filtered the dataset to include only entries for New York City.
#   - Isolated relevant columns, focusing on `RegionName` and all numeric columns representing dates.
#   - Transformed the dataset using the `melt` function in Pandas, converting date columns into rows for a more streamlined structure. The columns for this transformation were `RegionName` as `id_vars` and the numeric columns as values.
#   - Dropped rows with missing values in the newly created `rent` column to maintain data integrity.
#   - Renamed the `RegionName` column to `zipcode` for clarity and alignment with other datasets.
#   - Converted the `recorded_date` column to a datetime format to facilitate time-based analysis.

# %%
# this function is used to load and clean zillow data
def load_and_clean_zillow_data(zillow_datafile: Path)->pd.DataFrame:
    data = pd.read_csv(zillow_datafile)
    
    # Only get the data of "NY" state
    zillow_data_NY = data[data.City == "New York"]
    
    # Get DataFrame containing selected columns and all numeric columns
    numeric_columns = data.filter(regex='^\d').columns.tolist()
    zillow_NY_dataset = zillow_data_NY[["RegionName"] + numeric_columns]
    
    # Melt the DataFrame to transform the date columns into rows
    zillow_NY_dataset_melted = pd.melt(zillow_NY_dataset, id_vars=["RegionName"], var_name="recorded_date", value_name="rent")
    
    # Drop rows with missing values in the "value" column
    zillow_NY_dataset_melted = zillow_NY_dataset_melted.dropna(subset=["rent"])
    
    # Rename some columns
    zillow_NY_dataset_melted = zillow_NY_dataset_melted.rename(columns={"RegionName": "zipcode"})
    
    # Convert "date" column to date format
    zillow_NY_dataset_melted["recorded_date"] = pd.to_datetime(zillow_NY_dataset_melted["recorded_date"])
    
    return zillow_NY_dataset_melted

# %% [markdown]
# ### 5. Load all data
# - **Load Data:**
#   - Utilize the previously set functions to load each dataset.
#
# - **Verify Data:**
#   - For each loaded dataset, perform the following checks:
#     1. **Display Info:**
#        - Use the `.info()` method to get an overview of each dataset. This includes details like column names, data types, and the number of non-null values, which are crucial for assessing data completeness and structure.
#     2. **Display Initial Rows:**
#        - Employ the `.head()` method to view the first few rows of each dataset. This step is important for a preliminary check to ensure that the data is loaded correctly and matches the expected format.

# %%
## this function is used to load all dataset
def load_all_data()-> GeoDataFrame or pd.DataFrame:
    data_311 = load_and_clean_311_data()
    data_tree = download_and_clean_tree_data()
    data_zipcode = load_and_clean_zipcodes_data(ZIPCODE_DATA_FILE)
    data_zillow = load_and_clean_zillow_data(ZILLOW_DATA_FILE)
    
    return (
        data_311,
        data_tree,
        data_zipcode,
        data_zillow
    )

# %%
data_311, data_tree, data_zipcode, data_zillow = load_all_data()

# %%
# Show basic info about 311 dataframe
data_311.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 23807000 entries, 0 to 24627961
# Data columns (total 5 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   unique_key      int64
#  1   created_date    datetime64[ns]
#  2   complaint_type  object
#  3   zipcode         int64
#  4   location        geometry
# dtypes: datetime64[ns](1), geometry(1), int64(2), object(1)
# memory usage: 1.1+ GB

# %%
# Show first 5 entries about 311 dataframe
data_311.head()
# Out:
#    unique_key created_date  complaint_type  zipcode  \
# 0    59288833   2023-10-31  Food Poisoning    11103
# 1    59285818   2023-10-31  Food Poisoning    10016
# 2    59287303   2023-10-31  Food Poisoning    10280
# 3    59287302   2023-10-31  Food Poisoning    11372
# 4    59285819   2023-10-31  Food Poisoning    10021
#
#                      location
# 0  POINT (-73.91848 40.75963)
# 1  POINT (-73.97879 40.74432)
# 2  POINT (-74.01598 40.71110)
# 3  POINT (-73.89328 40.74881)
# 4  POINT (-73.95441 40.76886)

# %%
# Show basic info about tree dataframe
data_tree.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 509525 entries, 0 to 509524
# Data columns (total 6 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   tree_id   509525 non-null  int64
#  1   status    509525 non-null  object
#  2   health    485498 non-null  object
#  3   species   485498 non-null  object
#  4   zipcode   509525 non-null  int64
#  5   location  509525 non-null  geometry
# dtypes: geometry(1), int64(2), object(3)
# memory usage: 23.3+ MB

# %%
# Show first 5 entries about tree dataframe
data_tree.head()
# Out:
#    tree_id status health          species  zipcode                    location
# 0   180683  Alive   Fair        red maple    11375  POINT (-73.84422 40.72309)
# 1   200540  Alive   Fair          pin oak    11357  POINT (-73.81868 40.79411)
# 2   204026  Alive   Good      honeylocust    11211  POINT (-73.93661 40.71758)
# 3   204337  Alive   Good      honeylocust    11211  POINT (-73.93446 40.71354)
# 4   189565  Alive   Good  American linden    11215  POINT (-73.97598 40.66678)

# %%
# Show basic info about zipcode dataframe
data_zipcode.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 248 entries, 0 to 262
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   zipcode   248 non-null    int64
#  1   location  248 non-null    geometry
# dtypes: geometry(1), int64(1)
# memory usage: 5.8 KB

# %%
# Show first 5 entries about zipcode dataframe
data_zipcode.head()
# Out:
#    zipcode                                           location
# 0    11436  POLYGON ((-73.80585 40.68291, -73.80569 40.682...
# 1    11213  POLYGON ((-73.93740 40.67973, -73.93487 40.679...
# 2    11212  POLYGON ((-73.90294 40.67084, -73.90223 40.668...
# 3    11225  POLYGON ((-73.95797 40.67066, -73.95576 40.670...
# 4    11218  POLYGON ((-73.97208 40.65060, -73.97192 40.650...

# %%
# Show basic info about zillow dataframe
data_zillow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9039 entries, 5 to 15224
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   zipcode        9039 non-null   int64
#  1   recorded_date  9039 non-null   datetime64[ns]
#  2   rent           9039 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 282.5 KB

# %%
# Show first 5 entries about zillow dataframe
data_zillow.head()
# Out:
#     zipcode recorded_date         rent
# 5     11226    2015-01-31  1944.609891
# 7     10025    2015-01-31  3068.951823
# 13    11206    2015-01-31  2482.829299
# 14    11221    2015-01-31  2125.738807
# 20    11235    2015-01-31  1687.789898

# %% [markdown]
# ## Part 2: Storing Data
# In this part, the focus is on creating a PostgreSQL database and storing the processed data efficiently.
#
# - **Create PostgreSQL Database:**
#   - Establish a new PostgreSQL database named **"GroupProject"**.
#   - Within this database, create a **PostGIS extension**. PostGIS is an essential extension for handling geographical and location data, making it ideal for the datasets we have.
#
# - **Create Tables and Indexes:**
#   - In the "GroupProject" database, create four distinct tables corresponding to the datasets: data_311, data_tree, data_zipcode, and data_zillow.
#   - For 3 table, create **indexes** for geometry column.
#
# - **Write Data from DataFrames to Tables:**
#   - Transfer the data from the GeoPandas/Pandas DataFrames into the corresponding tables in the database.

# %% [markdown]
# ### 1. Create PostgreSQL Database and Set Postgis Extension

# %%
# first step: create database 'GroupProject'in PostgreSQL
# !createdb GroupProject
# Out:
# createdb: error: database creation failed: ERROR:  database "GroupProject" already exists

# %%
# second step: create postgis extension
# !psql --dbname GroupProject -c 'CREATE EXTENSION postgis;'
# Out:
# ERROR:  extension "postgis" already exists

# %% [markdown]
# ### 2. Create Tables and Indexes
#
# - Use **SQLAlchemy** to Create Tables
#     - **Function Definition for Table Creation**:
#       - Defined a function `create_tables` with the _engine_ as its parameter.
#       - Set primary keys and data types for each of the four tables: `nyc_311`, `nyc_tree`, `nyc_zipcode`, `nyc_zillow`.
#       - Bound table definitions to the engine using `MetaData` from SQLAlchemy. Invoked the `create_all` method to execute table creation in the database.
#
#     - **Establishing Database Connection**:
#       - Connected to the PostgreSQL database using the `create_engine` function from SQLAlchemy.
#       - Called the `create_tables` function to create tables in the database.
#
# - Use **psycopg2** to Create Indexes
#     - **Function Definition for Index Creation**:
#       - Defined a function `create_indexes` with the _connection_ as its parameter.
#       - Ran SQL commands to create GIST indexes on the `location` columns of `nyc_311`, `nyc_tree`, and `nyc_zipcode`.
#
#     - **Establishing Database Connection**:
#       - Connected to the database using the `psycopg2.connect` function.
#       - Called the `create_indexes` function to create indexes in the database.

# %%
# this function is used to create tables
def create_tables(engine):
    metadata = MetaData()

    nyc_311 = Table(
        'nyc_311', metadata,
        Column('unique_key', Integer, primary_key=True),
        Column('created_date', TIMESTAMP),
        Column('complaint_type', String),
        Column('zipcode', Integer),
        Column('location', Geometry('POINT', srid=4326))
    )

    nyc_tree = Table(
        'nyc_tree', metadata,
        Column('tree_id', Integer, primary_key=True),
        Column('status', String),
        Column('health', String),
        Column('species', String),
        Column('zipcode', Integer),
        Column('location', Geometry('POINT', srid=4326))
    )

    nyc_zipcode = Table(
        'nyc_zipcode', metadata,
        Column('zipcode', Integer, primary_key=True),
        Column('location', Geometry('POLYGON', srid=4326))
    )
    
    nyc_zillow = Table(
        'nyc_zillow', metadata,
        Column('zipcode', Integer, primary_key=True),
        Column('recorded_date', Date),
        Column('rent', Float)
    )

    metadata.create_all(engine)

# %%
# this function is used to create indexes
def create_indexes(connection):
    sql_create_indexes = """
    CREATE INDEX IF NOT EXISTS idx_nyc_311_location ON "nyc_311" USING gist (location);
    CREATE INDEX IF NOT EXISTS idx_nyc_tree_location ON "nyc_tree" USING gist (location);
    CREATE INDEX IF NOT EXISTS idx_nyc_zipcode_location ON "nyc_zipcode" USING gist (location);
    """

    with connection.cursor() as cursor:
        cursor.execute(sql_create_indexes)

# %%
# use sqlalchemy to create tables in the postgresql
engine = create_engine(DB_URL)
create_tables(engine)

# %%
# use psycopg2 to create indexes in the postgresql
with psycopg2.connect(DB_URL) as connection:
    create_indexes(connection)

# %% [markdown]
# ### Add Data to Database
# - **Define a Function to Write DataFrames to Tables**:
#   - Created a function `write_dataframes_to_table` with parameters _df_name_ (the DataFrame to be written) and _table_name_ (the target table in the database).
#   - Implemented a conditional check: if the DataFrame is a GeoPandas DataFrame, it utilizes the `to_postgis` method for writing spatial data. For regular Pandas DataFrames, the `to_sql` method is used.
#
# - **Execute Function for Data Insertion**:
#   - Called the `write_dataframes_to_table` function to transfer data from the four dataframes (`NYC311`, `NYCTree`, `NYC Zipcode`, `NYC Zillow`) into their respective tables in the database.

# %%
# this function is used to write date into tables
def write_dataframes_to_table(df_name:pd.DataFrame, table_name:str):
    engine = create_engine(DB_URL)
    
    # if it is geopandas dataframe, use "gpd.to_postgis", else use "pd.to_sql"
    try:
        df_name.to_postgis(table_name, engine, if_exists='replace', index=False)
    except:
        df_name.to_sql(table_name, engine, if_exists='replace', index=False)

# %%
write_dataframes_to_table(data_311, 'nyc_311')
write_dataframes_to_table(data_tree, 'nyc_tree')
write_dataframes_to_table(data_zipcode,"nyc_zipcode")
write_dataframes_to_table(data_zillow,"nyc_zillow")

# %% [markdown]
# ## Part 3: Understanding the Data

# %%
# Define a function to write the queries to file
# Setting the filename for the SQL query file
def write_query_to_file(query:str, file_name:Path):
    with open(file_name, 'w') as file:
        file.write(query)  # Writing the SQL query to the specified file

# %% [markdown]
# ### Query 1 : Which area might be more calm to live in?
# **Question:**
# Between October 1st, 2022 and September 30th, 2023 (inclusive), find the number of 311 complaints per zip code. The query result should have two columns, one row per zip code, with the number of complaints in descending order.
#
# **Solution:**
# - **Objective:** Analyze and count noise-related 311 complaints in New York City by zip code from October 1st, 2022, to September 30th, 2023.
# - **Method:** The code filters complaints from the nyc_311 database, groups them by zip code, and calculates the total number of noise complaints for each zip code.
# - **Sorting:** Results are sorted in descending order, showing zip codes with the most noise complaints first.
# - **Output:** Produces a table listing each zip code with its corresponding number of noise complaints, helping to identify areas with high noise issues.

# %%
# SQL query to find the number of 311 complaints per zip code
QUERY_1 = """
SELECT 
      zipcode, 
      COUNT(*) AS complaint_count
FROM 
      nyc_311
WHERE 
      created_date BETWEEN '2022-10-01' AND '2023-09-30'
      AND complaint_type LIKE '%Noise%'
GROUP BY 
      zipcode
ORDER BY 
      complaint_count DESC;
"""

# %%
# Print the result for the query 
with engine.connect() as conn:
    result = conn.execute(text(QUERY_1))
    print(f"Zip Code ｜ Complaint Count")
    for row in result:
        print(f"{row.zipcode}｜{row.complaint_count}")
# Out:
# Zip Code ｜ Complaint Count
# 10023｜15595
# 10031｜12439
# 10456｜12291
# 10025｜11903
# 10453｜11408
# 10457｜11086
# 10458｜10642
# 10032｜10619
# 10452｜10544
# 10468｜10309
# 11226｜10184
# 10466｜10067
# 11201｜10051
# 11221｜10017
# 11414｜9725
# 10002｜8889
# 11238｜8580
# 11207｜8504
# 10467｜8237
# 10033｜8201
# 10027｜8089
# 10034｜7676
# 11216｜7518
# 10011｜7290
# 11237｜7277
# 10009｜7234
# 11206｜6838
# 11368｜6710
# 10029｜6627
# 11208｜6505
# 10040｜6490
# 11225｜6374
# 10026｜6363
# 11211｜6193
# 11385｜6190
# 10472｜6178
# 11212｜6110
# 10463｜5922
# 10003｜5848
# 10460｜5705
# 10030｜5494
# 10019｜5461
# 10462｜5300
# 11233｜5239
# 11372｜4976
# 10016｜4970
# 11220｜4916
# 11366｜4886
# 11249｜4884
# 11419｜4860
# 11377｜4784
# 11213｜4757
# 11373｜4750
# 11433｜4723
# 10028｜4679
# 10024｜4556
# 11101｜4545
# 10451｜4464
# 10035｜4430
# 10455｜4402
# 11203｜4398
# 11217｜4346
# 10459｜4338
# 11231｜4297
# 11420｜4280
# 11103｜4217
# 11222｜4142
# 11375｜4011
# 11209｜3905
# 11235｜3618
# 10454｜3528
# 11215｜3525
# 10473｜3460
# 10036｜3445
# 11357｜3344
# 10014｜3340
# 10128｜3306
# 11435｜3286
# 11229｜3284
# 11223｜3269
# 11234｜3267
# 11218｜3222
# 10001｜3207
# 11230｜3201
# 10012｜3184
# 10461｜3164
# 11106｜3145
# 11224｜3022
# 11355｜2951
# 10469｜2909
# 11421｜2891
# 10039｜2853
# 11210｜2817
# 10301｜2712
# 11214｜2702
# 11232｜2681
# 11236｜2649
# 11205｜2641
# 11434｜2615
# 11691｜2607
# 11432｜2541
# 10013｜2506
# 11102｜2383
# 10465｜2372
# 11354｜2357
# 11204｜2244
# 11105｜2158
# 10314｜2088
# 10037｜2073
# 11417｜1910
# 11374｜1870
# 11219｜1845
# 11418｜1835
# 10304｜1834
# 10021｜1807
# 10038｜1803
# 10010｜1775
# 11356｜1669
# 11378｜1663
# 11104｜1632
# 10306｜1603
# 11436｜1602
# 11361｜1532
# 11369｜1522
# 11412｜1509
# 11365｜1476
# 11694｜1403
# 11358｜1368
# 11423｜1327
# 10470｜1325
# 11367｜1323
# 10065｜1297
# 10471｜1293
# 11428｜1292
# 10075｜1269
# 11692｜1267
# 10022｜1256
# 11416｜1177
# 10017｜1162
# 10305｜1157
# 11413｜1139
# 11415｜1119
# 11379｜1099
# 11422｜1031
# 11370｜990
# 10312｜982
# 10310｜922
# 10018｜913
# 11693｜896
# 11411｜834
# 10474｜817
# 10302｜793
# 11228｜787
# 11429｜767
# 10303｜763
# 11427｜718
# 11364｜701
# 10309｜669
# 10307｜609
# 10308｜568
# 10007｜532
# 10005｜530
# 11239｜525
# 11426｜445
# 10464｜442
# 10475｜435
# 11004｜431
# 11360｜419
# 10004｜328
# 10000｜241
# 11362｜224
# 10006｜223
# 10044｜218
# 11109｜216
# 10280｜175
# 10282｜167
# 11363｜104
# 10069｜99
# 11040｜77
# 11001｜57
# 11359｜44
# 10020｜18
# 11005｜17
# 10105｜16
# 10120｜12
# 10162｜11
# 10110｜10
# 11697｜8
# 10106｜8
# 10281｜6
# 10169｜5
# 11430｜4
# 10121｜4
# 10118｜4
# 10154｜4
# 10278｜3
# 10172｜3
# 10103｜3
# 10112｜3
# 10178｜3
# 12345｜2
# 10158｜2
# 10153｜2
# 10048｜2
# 11241｜2
# 10041｜2
# 11251｜2
# 10165｜1
# 10166｜1
# 11242｜1
# 10045｜1
# 10271｜1
# 10171｜1
# 10119｜1
# 10123｜1
# 10155｜1
# 10279｜1

# %%
# Setting the filename for the SQL query file
QUERY_1_FILENAME = QUERY_DIR / "top_zipcodes_by_complaints.sql"
write_query_to_file(QUERY_1, QUERY_1_FILENAME)

# %% [markdown]
# ### Query 2: Where has the most greenery?
# **Question:** Using just the trees table, which 10 zip codes have the most trees? The query result should have two columns, 10 rows. The rows should be sorted by the total number of trees, descending.
#
# **Solution:**
# - **Objective:** Identify the top 10 zip codes in New York City with the highest number of living trees.
# - **Method:** The code queries the nyc_tree database, focusing on 'Alive' trees, groups them by zip code, and counts the trees in each zip code.
# - **Sorting and Limiting:** Results are sorted in descending order of tree count, and the query is limited to the top 10 zip codes with the most trees.
# - **Output:** Produces a table displaying the 10 zip codes with the highest number of trees, offering insights into the areas with the most greenery.

# %%
# SQL query to find the number of trees per zip code
QUERY_2 = """
SELECT 
     zipcode, 
     COUNT(*) AS tree_count
FROM 
     nyc_tree
WHERE 
     status = 'Alive'
GROUP BY 
     zipcode
ORDER BY 
     tree_count DESC
LIMIT 10;
"""

# %%
# Print the result for the query 
with engine.connect() as conn:
    result = conn.execute(text(QUERY_2))
    print(f"Zip Code| Tree Count")
    for row in result:
        print(f"{row.zipcode}| {row.tree_count}")
# Out:
# Zip Code| Tree Count
# 10312| 20155
# 10314| 15291
# 10306| 11905
# 10309| 11133
# 11208| 7762
# 11207| 7456
# 11385| 7382
# 11230| 6936
# 10308| 6479
# 10305| 6239

# %%
# Setting the filename for the SQL query file
QUERY_2_FILENAME = QUERY_DIR / "zipcodes_by_tree_count.sq"
write_query_to_file(QUERY_2, QUERY_2_FILENAME)

# %% [markdown]
# ### Query 3: Can I afford a place in the areas with the most trees?
# **Question:** Of the 10 zip codes with the most trees, for the month of August 2023, what is the average rent by zip code? The query should have a JOIN statement. The query result should have two columns (not three) and 10 rows. The rows should be sorted by the total number of trees, descending. “Humanize” the rent numbers, meaning format the results as 2,879.58 instead of 2879.575128.
#
# **Solution:**
# - **Objective:** Determine the average rent for August 2023 in the top 10 tree-rich zip codes in New York City.
# - **Method:** The code first identifies the 10 zip codes with the most living trees, then joins this data with the nyc_zillow database to calculate the average rent in these areas for August 2023.
# - **Formatting:** The average rent is formatted to be human-readable, displaying numbers in a standard currency format (e.g., 2,879.58).
# - **Output:** Generates a table listing each of the top 10 tree-rich zip codes with their corresponding average rent, sorted by the number of trees in descending order.

# %%
# SQL query to find the zip code with most trees
QUERY_3 = """
SELECT 
    tc.zipcode, 
    TO_CHAR(AVG(z.rent), 'FM9,999,999.00') as average_rent
FROM 
    (
        SELECT 
            zipcode, 
            COUNT(*) AS tree_count
        FROM 
            nyc_tree
        WHERE 
            status = 'Alive'
        GROUP BY 
            zipcode
        ORDER BY 
            COUNT(*) DESC
        LIMIT 10
    ) AS tc
JOIN 
    nyc_zillow z ON tc.zipcode = z.zipcode
WHERE 
    z.recorded_date BETWEEN '2023-08-01' AND '2023-08-31'
GROUP BY 
    tc.zipcode, tc.tree_count
ORDER BY 
    tc.tree_count DESC
"""

# %%
# Print the result for the query 
with engine.connect() as conn:
    result = conn.execute(text(QUERY_3))
    print(f"Zip Code| Average Rent")
    for row in result:
        print(f"{row.zipcode}|{row.average_rent}")
# Out:
# Zip Code| Average Rent
# 10312|1,775.09
# 10314|2,465.47
# 10306|2,331.54
# 10309|1,832.01
# 11208|2,737.55
# 11207|3,079.09
# 11385|3,064.48
# 11230|2,657.04
# 10305|2,176.37

# %%
# Setting the filename for the SQL query file
QUERY_3_FILENAME = QUERY_DIR / "average_rent_top_tree_zipcodes.sql"
write_query_to_file(QUERY_3, QUERY_3_FILENAME)

# %% [markdown]
# ### Query 4: Could there be a correlation between an area’s rent, the number of its trees, and the number of 311 complaints?
#
# **Question:** For the month of January 2023, return the 5 zip codes with the lowest average rent, and 5 zipcodes of the highest average rent, and include the tree count and complaint count for each zip code by using JOIN statements. The query result should have 4 columns (zip code, average rent, tree count, and complaint count) and 10 rows: five with the highest average rent, and five with the lowest average rent. “Humanize” the rent numbers, meaning format the results as 2,879.58 instead of 2879.575128.
#
# **Solution:**
# - **Objective:** Explore potential correlations between average rent, tree count, and 311 complaint count in NYC zip codes for January 2023, focusing on the five zip codes with the highest and lowest average rents.
# - **Method:** The code performs a complex analysis involving multiple JOIN statements. It first calculates the average rent for each zip code, then ranks them to identify the top and bottom five. It also aggregates tree and complaint counts for these zip codes.
# - **Formatting:** Average rent values are formatted for readability (e.g., 2,879.58 instead of 2879.575128).
# - **Output:** Generates a table with 10 rows, listing the zip codes with the five highest and five lowest average rents, along with their corresponding tree and complaint counts, to investigate potential correlations.

# %%
# SQL query to find the correlation between rent, trees and complaints
QUERY_4 = """
WITH RentData AS (
    SELECT 
        zipcode, 
        AVG(rent) AS average_rent
    FROM 
        nyc_zillow
    WHERE 
        recorded_date BETWEEN '2023-01-01' AND '2023-01-31'
    GROUP BY 
        zipcode
), RentRank AS (
    SELECT 
        zipcode, 
        average_rent,
        RANK() OVER (ORDER BY average_rent DESC) AS high_rank,
        RANK() OVER (ORDER BY average_rent ASC) AS low_rank
    FROM 
        RentData
), TreeData AS (
    SELECT 
        zipcode, 
        COUNT(*) AS tree_count
    FROM 
        nyc_tree
    WHERE 
        status = 'Alive'
    GROUP BY 
        zipcode
), ComplaintData AS (
    SELECT 
        zipcode, 
        COUNT(*) AS complaint_count
    FROM 
        nyc_311
    WHERE 
        created_date BETWEEN '2023-01-01' AND '2023-01-31'
    GROUP BY 
        zipcode
)
SELECT 
    r.zipcode, 
    TO_CHAR(r.average_rent, 'FM9,999,999.00') as formatted_rent, 
    t.tree_count, 
    c.complaint_count
FROM 
    RentRank r
JOIN 
    TreeData t ON r.zipcode = t.zipcode
JOIN 
    ComplaintData c ON r.zipcode = c.zipcode
WHERE 
    r.high_rank <= 5 OR r.low_rank <= 5
ORDER BY 
    r.high_rank, r.low_rank
"""

# %%
# Print the result for the query 
with engine.connect() as conn:
    result = conn.execute(text(QUERY_4))
    print("Zipcode |  Average Rent |  Tree Count |  Complaint Count")
    for row in result:
        print(f"{row.zipcode} |  {row.formatted_rent} |  {row.tree_count} |  {row.complaint_count}")
# Out:
# Zipcode |  Average Rent |  Tree Count |  Complaint Count
# 10007 |  7,270.24 |  338 |  250
# 10282 |  7,143.35 |  230 |  39
# 10013 |  5,480.11 |  1132 |  740
# 10069 |  4,959.67 |  112 |  35
# 10011 |  4,741.87 |  2040 |  1487
# 10458 |  1,883.08 |  3012 |  3587
# 11357 |  1,829.66 |  2339 |  900
# 10453 |  1,820.23 |  2752 |  2941
# 10462 |  1,801.89 |  3973 |  2276
# 10309 |  1,380.51 |  11133 |  800

# %%
# Setting the filename for the SQL query file
QUERY_4_FILENAME = QUERY_DIR / "rent_tree_complaint_correlation.sql"
write_query_to_file(QUERY_4, QUERY_4_FILENAME)

# %% [markdown]
# ### Query 5: Where has the most greenery (take 2)?
# **Question:** Rewrite Query 2 to use both the trees table and the zipcodes table. Join both tables where the coordinate point of the tree is inside the polygon boundary of the zipcode as defined in the zipcode table. The query should have a JOIN statement. The query results should match exactly the results of Query 2.
#
# **Solution:**
# - **Objective:** Refine the analysis of the amount of greenery (living trees) in each zip code, using both the nyc_tree and nyc_zipcode tables, with spatial data to accurately match trees to zip codes.
# - **Method:** The code joins the tree data with zip code boundaries, counting trees only if they are physically located within the zip code's boundaries.
# - **Spatial Analysis:** Utilizes ST_Contains to ensure that only trees within the geographic boundary of each zip code are counted.
# - **Output:** Produces a list, limited to 2 zip codes, showing the number of living trees in each zip code, ordered by the tree count in descending order.

# %%
# SQL query to find the number of trees per zip code
QUERY_5 = """
SELECT 
     z.zipcode, 
     COUNT(*) as tree_count
FROM 
     nyc_tree t
JOIN 
     nyc_zipcode z ON ST_Contains(z.location, t.location)
WHERE 
     t.status = 'Alive'
GROUP BY 
     z.zipcode
ORDER BY 
     tree_count DESC
LIMIT 2;
"""

# %%
# Print the result for the query 
with engine.connect() as conn:
    result = conn.execute(text(QUERY_5))
    print("Zipcode | Tree Count")
    for row in result:
        print(f"{row.zipcode} | {row.tree_count}")
# Out:
# Zipcode | Tree Count
# 10312 | 20155
# 10314 | 15291

# %%
# Setting the filename for the SQL query file
QUERY_5_FILENAME = QUERY_DIR / "greenery_with_zipcode_spatial_join.sql"
write_query_to_file(QUERY_5, QUERY_5_FILENAME)

# %% [markdown]
# ### Query 6: What is the immediate area like?
# **Question:** Using the following coordinate pair on campus, which trees are within ½ mile radius of this point? (Latitude: 40.80737875669467, Longitude: -73.96253174434912)The result should have 5 columns (ID, species, health, status, and coordinate location of each tree). You may use regular Python to help construct the geometric object needed for setting the radius in the query.
#
# **Solution:**
# - **Objective:** Identify trees within a ½ mile radius of a specific coordinate point on a campus.
# - **Method:** The code utilizes a spatial query (ST_DWithin) in the nyc_tree database to find trees within 804.672 meters of the given coordinates.
# - **Data Columns:** The output includes the tree ID, species, health status, current status, and the exact geographic location of each tree.
# - **Output:** Generates a table listing trees within the specified radius, providing detailed information about each tree, which helps in understanding the immediate greenery around the given point.

# %%
# SQL query to find the coordinate pair of trees
QUERY_6 = f"""
SELECT 
     tree_id, 
     species, 
     health, 
     status, 
     ST_AsText(location) AS location
FROM 
     nyc_tree
WHERE 
     ST_DWithin(location, '{point_wkt}'::geography, 804.672)
"""

# %%
# Print the result for the query 
with engine.connect() as conn:
    result = conn.execute(text(QUERY_6))
    print("ID | Species | Health | Status | Location")
    for row in result:
        print(f"{row.tree_id} | {row.species} | {row.health} | {row.status} | {row.location}")
# Out:
# ID | Species | Health | Status | Location
# 198514 | pin oak | Good | Alive | POINT(-73.9620798 40.80230109)
# 209919 | London planetree | Good | Alive | POINT(-73.96331506 40.80881155)
# 209921 | London planetree | Good | Alive | POINT(-73.96340334 40.80874458)
# 203887 | willow oak | Good | Alive | POINT(-73.96071917 40.80572583)
# 196440 | American elm | Fair | Alive | POINT(-73.96412322 40.81114538)
# 209913 | pin oak | Good | Alive | POINT(-73.96312072 40.80907709)
# 196605 | American elm | Good | Alive | POINT(-73.96715782 40.80738644)
# 196614 | None | None | Stump | POINT(-73.96769955 40.80650311)
# 188558 | London planetree | Good | Alive | POINT(-73.96052882 40.80361816)
# 204127 | Japanese zelkova | Fair | Alive | POINT(-73.96208728 40.80521641)
# 188841 | honeylocust | Good | Alive | POINT(-73.95822529 40.8088019)
# 190326 | Japanese zelkova | Good | Alive | POINT(-73.95627225 40.80385376)
# 189406 | ginkgo | Fair | Alive | POINT(-73.95892624 40.80767399)
# 198510 | pin oak | Good | Alive | POINT(-73.96252446 40.80248808)
# 209824 | pin oak | Good | Alive | POINT(-73.9617956 40.81089603)
# 189410 | None | None | Dead | POINT(-73.95938819 40.80786902)
# 138615 | golden raintree | Fair | Alive | POINT(-73.95427116 40.80900142)
# 188843 | ginkgo | Good | Alive | POINT(-73.95801583 40.80871253)
# 203994 | Callery pear | Fair | Alive | POINT(-73.96171282 40.80544227)
# 209834 | pin oak | Fair | Alive | POINT(-73.96237155 40.81010258)
# 193107 | pin oak | Good | Alive | POINT(-73.96555738 40.80283627)
# 121484 | Schumard's oak | Poor | Alive | POINT(-73.96312927 40.80256195)
# 198515 | pin oak | Good | Alive | POINT(-73.96193064 40.80223836)
# 196613 | green ash | Fair | Alive | POINT(-73.96766169 40.80656601)
# 190331 | Japanese zelkova | Good | Alive | POINT(-73.9568291 40.80408682)
# 189405 | ginkgo | Fair | Alive | POINT(-73.95882551 40.80763146)
# 189413 | ginkgo | Poor | Alive | POINT(-73.95972638 40.8080118)
# 198511 | pin oak | Good | Alive | POINT(-73.96241701 40.80244289)
# 209911 | pin oak | Good | Alive | POINT(-73.96307592 40.80919195)
# 209912 | pin oak | Good | Alive | POINT(-73.9630763 40.80913778)
# 190330 | Japanese zelkova | Good | Alive | POINT(-73.95672722 40.80404418)
# 188839 | ginkgo | Fair | Alive | POINT(-73.95850941 40.8089231)
# 188840 | ginkgo | Fair | Alive | POINT(-73.95837743 40.8088668)
# 196543 | honeylocust | Good | Alive | POINT(-73.96564723 40.80908661)
# 196544 | honeylocust | Good | Alive | POINT(-73.96569063 40.80902644)
# 189409 | ginkgo | Good | Alive | POINT(-73.95927989 40.8078233)
# 209832 | pin oak | Good | Alive | POINT(-73.96234526 40.81019253)
# 188664 | northern red oak | Good | Alive | POINT(-73.95925026 40.8063837)
# 188561 | London planetree | Good | Alive | POINT(-73.96042285 40.80392477)
# 209918 | London planetree | Fair | Alive | POINT(-73.96331506 40.80881155)
# 209920 | London planetree | Good | Alive | POINT(-73.96337335 40.80873191)
# 203995 | Callery pear | Poor | Alive | POINT(-73.96158371 40.80538715)
# 198509 | pin oak | Good | Alive | POINT(-73.96278614 40.80259812)
# 188559 | London planetree | Good | Alive | POINT(-73.96049331 40.80372089)
# 196616 | Sophora | Fair | Alive | POINT(-73.96778354 40.80634619)
# 209833 | pin oak | Good | Alive | POINT(-73.96233482 40.81015301)
# 188560 | London planetree | Good | Alive | POINT(-73.96045753 40.80382443)
# 187078 | Japanese zelkova | Good | Alive | POINT(-73.95997285 40.80083357)
# 188663 | northern red oak | Good | Alive | POINT(-73.95930941 40.80630254)
# 188665 | northern red oak | Good | Alive | POINT(-73.95919495 40.80645957)
# 209915 | pin oak | Good | Alive | POINT(-73.9631618 40.80902096)
# 190327 | Japanese zelkova | Good | Alive | POINT(-73.95644563 40.80392633)
# 190328 | Japanese zelkova | Good | Alive | POINT(-73.95654498 40.80396791)
# 193104 | honeylocust | Good | Alive | POINT(-73.96587679 40.80297134)
# 188666 | northern red oak | Good | Alive | POINT(-73.95916643 40.80649871)
# 190329 | Japanese zelkova | Good | Alive | POINT(-73.95664496 40.80400975)
# 193105 | honeylocust | Good | Alive | POINT(-73.96579157 40.8029353)
# 196534 | None | None | Stump | POINT(-73.965089 40.80986073)
# 193109 | honeylocust | Good | Alive | POINT(-73.96536485 40.80275485)
# 193111 | honeylocust | Good | Alive | POINT(-73.9651215 40.80265195)
# 209916 | pin oak | Good | Alive | POINT(-73.96324955 40.80895471)
# 193115 | northern red oak | Good | Alive | POINT(-73.96452656 40.80240036)
# 209993 | pin oak | Fair | Alive | POINT(-73.96496366 40.80660709)
# 193163 | northern red oak | Good | Alive | POINT(-73.96177571 40.80124342)
# 188668 | northern red oak | Good | Alive | POINT(-73.95908312 40.806613)
# 193167 | American linden | Poor | Alive | POINT(-73.96212892 40.80139215)
# 210161 | London planetree | Good | Alive | POINT(-73.96590138 40.8052723)
# 210163 | London planetree | Good | Alive | POINT(-73.96593682 40.80522321)
# 209776 | pin oak | Good | Alive | POINT(-73.96127236 40.81158252)
# 196530 | None | None | Stump | POINT(-73.96454237 40.81060612)
# 182931 | Chinese elm | Good | Alive | POINT(-73.95470532 40.80330474)
# 182933 | Japanese zelkova | Good | Alive | POINT(-73.95495862 40.80341155)
# 193110 | None | None | Dead | POINT(-73.96522629 40.80269626)
# 196533 | Chinese elm | Good | Alive | POINT(-73.9649539 40.81004134)
# 196579 | None | None | Dead | POINT(-73.96687204 40.80779441)
# 196531 | Chinese elm | Fair | Alive | POINT(-73.96470124 40.81038808)
# 210002 | crab apple | Good | Alive | POINT(-73.96522107 40.80620083)
# 183144 | honeylocust | Fair | Alive | POINT(-73.95415551 40.80400072)
# 183146 | honeylocust | Good | Alive | POINT(-73.95440708 40.80410707)
# 193170 | Callery pear | Good | Alive | POINT(-73.96252667 40.80155965)
# 209774 | crab apple | Good | Alive | POINT(-73.96124967 40.81161408)
# 209777 | pin oak | Good | Alive | POINT(-73.96128605 40.81150908)
# 217949 | ginkgo | Good | Alive | POINT(-73.96816644 40.80311093)
# 217951 | ginkgo | Good | Alive | POINT(-73.96844939 40.80322975)
# 209859 | crab apple | Poor | Alive | POINT(-73.96261324 40.80977045)
# 196540 | honeylocust | Good | Alive | POINT(-73.96544067 40.80937306)
# 196536 | honeylocust | Good | Alive | POINT(-73.96517857 40.80973653)
# 196538 | honeylocust | Good | Alive | POINT(-73.96534763 40.80950208)
# 217947 | ginkgo | Fair | Alive | POINT(-73.96797644 40.80303115)
# 209858 | crab apple | Poor | Alive | POINT(-73.96262666 40.80980549)
# 207104 | honeylocust | Good | Alive | POINT(-73.95745741 40.80170019)
# 193169 | Callery pear | Good | Alive | POINT(-73.96239903 40.8015059)
# 210167 | London planetree | Fair | Alive | POINT(-73.96606101 40.80505114)
# 182935 | Japanese zelkova | Good | Alive | POINT(-73.95535973 40.80358069)
# 209863 | pin oak | Poor | Alive | POINT(-73.96268749 40.80967024)
# 190324 | American elm | Good | Alive | POINT(-73.95607926 40.80377298)
# 193164 | American elm | Poor | Alive | POINT(-73.96192009 40.80130422)
# 209773 | None | None | Dead | POINT(-73.96121955 40.81160158)
# 210165 | London planetree | Fair | Alive | POINT(-73.96602735 40.805152)
# 209866 | pin oak | Fair | Alive | POINT(-73.96277535 40.80960482)
# 209826 | pin oak | Fair | Alive | POINT(-73.96189291 40.81081616)
# 214738 | ginkgo | Fair | Alive | POINT(-73.96453698 40.80681876)
# 209857 | crab apple | Poor | Alive | POINT(-73.96260947 40.80982869)
# 217953 | ginkgo | Good | Alive | POINT(-73.96878166 40.80336928)
# 214739 | ginkgo | Fair | Alive | POINT(-73.96445999 40.80692442)
# 214741 | ginkgo | Fair | Alive | POINT(-73.96434625 40.8070805)
# 183149 | honeylocust | Good | Alive | POINT(-73.9548856 40.80430936)
# 122014 | dawn redwood | Fair | Alive | POINT(-73.96318663 40.80030239)
# 207094 | ginkgo | Good | Alive | POINT(-73.95839117 40.80086888)
# 209922 | London planetree | Fair | Alive | POINT(-73.96343231 40.808705)
# 196619 | green ash | Good | Alive | POINT(-73.96791598 40.80609322)
# 190357 | green ash | Fair | Alive | POINT(-73.95793759 40.80455495)
# 214740 | ginkgo | Poor | Alive | POINT(-73.96441449 40.80698685)
# 203844 | common hackberry | Poor | Alive | POINT(-73.96105405 40.80433701)
# 207301 | Japanese zelkova | Good | Alive | POINT(-73.9575928 40.80383519)
# 138837 | paper birch | Fair | Alive | POINT(-73.95424817 40.81051518)
# 138838 | paper birch | Good | Alive | POINT(-73.95431476 40.81054278)
# 203842 | common hackberry | Poor | Alive | POINT(-73.96211389 40.80478525)
# 203846 | common hackberry | Fair | Alive | POINT(-73.96070183 40.80418803)
# 188842 | Sophora | Good | Alive | POINT(-73.95812198 40.80875782)
# 210124 | crab apple | Good | Alive | POINT(-73.96545254 40.80593834)
# 207205 | honeylocust | Good | Alive | POINT(-73.95710786 40.8025625)
# 196442 | American elm | Fair | Alive | POINT(-73.96427309 40.81094364)
# 207207 | honeylocust | Good | Alive | POINT(-73.95734324 40.8026616)
# 225206 | American linden | Fair | Alive | POINT(-73.95788794 40.80218015)
# 207206 | honeylocust | Fair | Alive | POINT(-73.95720265 40.80260241)
# 225208 | American linden | Good | Alive | POINT(-73.95814135 40.80228736)
# 209961 | None | None | Stump | POINT(-73.9646179 40.80708452)
# 210173 | magnolia | Good | Alive | POINT(-73.96617586 40.80494624)
# 207209 | silver linden | Good | Alive | POINT(-73.95793312 40.80290995)
# 210134 | crab apple | Good | Alive | POINT(-73.96571156 40.80558361)
# 222717 | honeylocust | Good | Alive | POINT(-73.96366257 40.80132547)
# 207147 | Sophora | Good | Alive | POINT(-73.9572428 40.80199297)
# 209962 | pin oak | Good | Alive | POINT(-73.96461143 40.80703903)
# 207294 | Callery pear | Good | Alive | POINT(-73.95729851 40.80450149)
# 222752 | Japanese zelkova | Good | Alive | POINT(-73.96454702 40.801845)
# 196577 | white ash | Poor | Alive | POINT(-73.9666772 40.80805502)
# 159206 | hardy rubber tree | Fair | Alive | POINT(-73.9634945 40.80111719)
# 209926 | London planetree | Fair | Alive | POINT(-73.96352187 40.80852897)
# 209927 | London planetree | Fair | Alive | POINT(-73.96357715 40.8085071)
# 209929 | London planetree | Fair | Alive | POINT(-73.9636093 40.80840951)
# 209837 | crab apple | Poor | Alive | POINT(-73.96243463 40.81006981)
# 210133 | crab apple | Good | Alive | POINT(-73.96569789 40.80560233)
# 225088 | ginkgo | Fair | Alive | POINT(-73.95892016 40.80097854)
# 225091 | ginkgo | Good | Alive | POINT(-73.95925596 40.80111886)
# 203845 | common hackberry | Fair | Alive | POINT(-73.96080598 40.80423208)
# 196535 | Sophora | Fair | Alive | POINT(-73.96513656 40.80979478)
# 207150 | Sophora | Good | Alive | POINT(-73.95701187 40.80230743)
# 193180 | None | None | Stump | POINT(-73.96346341 40.8019541)
# 225026 | Sophora | Good | Alive | POINT(-73.96461106 40.80212197)
# 225028 | Sophora | Good | Alive | POINT(-73.96451193 40.80225815)
# 222755 | Sophora | Good | Alive | POINT(-73.96440274 40.80204029)
# 193114 | common hackberry | Good | Alive | POINT(-73.96473929 40.80249032)
# 121485 | Schumard's oak | Good | Alive | POINT(-73.9633269 40.80264431)
# 214748 | black locust | Poor | Alive | POINT(-73.96315113 40.80872052)
# 203847 | common hackberry | Good | Alive | POINT(-73.96060399 40.80414665)
# 231989 | London planetree | Good | Alive | POINT(-73.95643113 40.80496262)
# 209839 | crab apple | Fair | Alive | POINT(-73.96244968 40.81004916)
# 225090 | ginkgo | Poor | Alive | POINT(-73.95920121 40.80109598)
# 210135 | crab apple | Good | Alive | POINT(-73.96569715 40.8055496)
# 207302 | None | None | Dead | POINT(-73.95627838 40.80331473)
# 210132 | pin oak | Good | Alive | POINT(-73.96564913 40.80561536)
# 231986 | pin oak | Good | Alive | POINT(-73.95595876 40.80476377)
# 231984 | pin oak | Good | Alive | POINT(-73.95560488 40.8046148)
# 198529 | American elm | Good | Alive | POINT(-73.96042612 40.80164326)
# 198533 | American elm | Good | Alive | POINT(-73.96004773 40.80148318)
# 198534 | American elm | Good | Alive | POINT(-73.95994706 40.80144059)
# 198525 | willow oak | Poor | Alive | POINT(-73.96063153 40.80170032)
# 198527 | willow oak | Good | Alive | POINT(-73.96054285 40.8016628)
# 187708 | honeylocust | Good | Alive | POINT(-73.9537557 40.80677466)
# 231985 | pin oak | Good | Alive | POINT(-73.95575275 40.80467705)
# 247595 | pin oak | Good | Alive | POINT(-73.95481493 40.80594216)
# 187704 | honeylocust | Good | Alive | POINT(-73.95394592 40.80651209)
# 187707 | honeylocust | Good | Alive | POINT(-73.95381597 40.80669146)
# 211531 | Chinese elm | Fair | Alive | POINT(-73.96716178 40.80322812)
# 207210 | golden raintree | Good | Alive | POINT(-73.95804054 40.80295518)
# 247598 | pin oak | Good | Alive | POINT(-73.95510326 40.80606324)
# 214710 | pin oak | Fair | Alive | POINT(-73.96485522 40.80638153)
# 222719 | honeylocust | Good | Alive | POINT(-73.96381669 40.80139047)
# 240335 | honeylocust | Good | Alive | POINT(-73.9588984 40.80755138)
# 225212 | American linden | Good | Alive | POINT(-73.95823075 40.80296072)
# 217547 | None | None | Stump | POINT(-73.96828196 40.80160483)
# 247575 | Japanese zelkova | Good | Alive | POINT(-73.95693893 40.80424321)
# 247577 | Japanese zelkova | Good | Alive | POINT(-73.95667545 40.80413224)
# 211611 | Chinese elm | Good | Alive | POINT(-73.9641482 40.80276468)
# 211609 | Chinese elm | Good | Alive | POINT(-73.96420727 40.802649)
# 222754 | Sophora | Fair | Alive | POINT(-73.96444075 40.80198884)
# 225086 | ginkgo | Good | Alive | POINT(-73.9587233 40.80089627)
# 209835 | crab apple | Fair | Alive | POINT(-73.96239691 40.81006776)
# 247587 | honeylocust | Good | Alive | POINT(-73.95701744 40.80521024)
# 225164 | American linden | Good | Alive | POINT(-73.95824443 40.80151023)
# 210159 | magnolia | Good | Alive | POINT(-73.96588575 40.80529396)
# 210172 | magnolia | Good | Alive | POINT(-73.96614578 40.8049337)
# 225163 | Sophora | Good | Alive | POINT(-73.95807417 40.80143848)
# 210156 | magnolia | Good | Alive | POINT(-73.96586334 40.80532501)
# 210158 | magnolia | Good | Alive | POINT(-73.96590124 40.80532672)
# 225046 | ginkgo | Good | Alive | POINT(-73.96165427 40.80107465)
# 76461 | Japanese tree lilac | Good | Alive | POINT(-73.96756462 40.8044429)
# 247608 | London planetree | Fair | Alive | POINT(-73.95511912 40.80748782)
# 225042 | Callery pear | Poor | Alive | POINT(-73.96185133 40.80080587)
# 135327 | Chinese fringetree | Good | Alive | POINT(-73.95757479 40.8095723)
# 247661 | honeylocust | Good | Alive | POINT(-73.95662838 40.80541445)
# 225203 | American linden | Poor | Alive | POINT(-73.95747146 40.80189212)
# 225202 | American linden | Fair | Alive | POINT(-73.95758296 40.80193912)
# 225199 | American linden | Good | Alive | POINT(-73.95783627 40.80204591)
# 247662 | ginkgo | Good | Alive | POINT(-73.95658075 40.80547912)
# 188838 | Kentucky coffeetree | Good | Alive | POINT(-73.95860516 40.80896395)
# 255382 | ginkgo | Fair | Alive | POINT(-73.96377474 40.80455077)
# 255383 | ginkgo | Fair | Alive | POINT(-73.9638568 40.80458547)
# 255091 | ginkgo | Fair | Alive | POINT(-73.96482239 40.80510329)
# 247781 | honeylocust | Good | Alive | POINT(-73.95729408 40.80667893)
# 247782 | honeylocust | Good | Alive | POINT(-73.95741011 40.8065188)
# 255379 | honeylocust | Fair | Alive | POINT(-73.96349068 40.80443063)
# 240668 | American elm | Fair | Alive | POINT(-73.95942964 40.80885798)
# 225197 | northern red oak | Good | Alive | POINT(-73.95835868 40.80226614)
# 255396 | Callery pear | Poor | Alive | POINT(-73.96504985 40.80509003)
# 247771 | Sophora | Good | Alive | POINT(-73.95791135 40.80538572)
# 255391 | ginkgo | Good | Alive | POINT(-73.96458904 40.80489515)
# 255392 | ginkgo | Poor | Alive | POINT(-73.96466163 40.80492585)
# 255094 | American linden | Fair | Alive | POINT(-73.96432957 40.80489567)
# 247602 | pin oak | Good | Alive | POINT(-73.95538748 40.80618259)
# 178550 | Norway maple | Good | Alive | POINT(-73.95739877 40.80690345)
# 189403 | Callery pear | Fair | Alive | POINT(-73.95861206 40.80754134)
# 189412 | None | None | Dead | POINT(-73.95964901 40.80797914)
# 196606 | honeylocust | Good | Alive | POINT(-73.96719944 40.80732247)
# 198512 | pin oak | Good | Alive | POINT(-73.96230577 40.80239611)
# 196541 | honeylocust | Good | Alive | POINT(-73.9654983 40.80929314)
# 209820 | pin oak | Fair | Alive | POINT(-73.96171153 40.81106551)
# 76462 | Japanese tree lilac | Good | Alive | POINT(-73.96750159 40.80441608)
# 193108 | pin oak | Fair | Alive | POINT(-73.96545669 40.80279369)
# 214747 | black locust | Fair | Alive | POINT(-73.96329637 40.80852122)
# 188547 | London planetree | Good | Alive | POINT(-73.96096912 40.80234416)
# 193112 | honeylocust | Good | Alive | POINT(-73.96502208 40.80260991)
# 196546 | green ash | Fair | Alive | POINT(-73.96633015 40.80838469)
# 187076 | Japanese zelkova | Good | Alive | POINT(-73.96007335 40.80069671)
# 209914 | None | None | Dead | POINT(-73.96317792 40.80905258)
# 209830 | pin oak | Good | Alive | POINT(-73.96225554 40.81031573)
# 209821 | None | None | Stump | POINT(-73.9617636 40.81099392)
# 209823 | None | None | Stump | POINT(-73.96180432 40.81093795)
# 209992 | pin oak | Fair | Alive | POINT(-73.96493365 40.80659444)
# 193171 | honeylocust | Good | Alive | POINT(-73.9626066 40.80159331)
# 187024 | honeylocust | Good | Alive | POINT(-73.96318229 40.80407594)
# 187023 | honeylocust | Good | Alive | POINT(-73.96322643 40.80401577)
# 193172 | honeylocust | Good | Alive | POINT(-73.96268622 40.80162683)
# 193174 | American linden | Good | Alive | POINT(-73.9628445 40.80169348)
# 188693 | willow oak | Fair | Alive | POINT(-73.958356 40.80760658)
# 188544 | London planetree | Good | Alive | POINT(-73.96110041 40.80196427)
# 193176 | Callery pear | Good | Alive | POINT(-73.96317528 40.80183277)
# 196578 | None | None | Dead | POINT(-73.96675856 40.8079462)
# 188669 | northern red oak | Good | Alive | POINT(-73.95903674 40.80667663)
# 196532 | Chinese elm | Good | Alive | POINT(-73.96486956 40.81015708)
# 182936 | Chinese elm | Good | Alive | POINT(-73.95543332 40.80361172)
# 209999 | northern red oak | Good | Alive | POINT(-73.96515907 40.80633949)
# 207105 | honeylocust | Good | Alive | POINT(-73.95740932 40.80176592)
# 218087 | honeylocust | Good | Alive | POINT(-73.96741828 40.80347733)
# 217952 | ginkgo | Good | Alive | POINT(-73.96857522 40.80328259)
# 209856 | crab apple | Fair | Alive | POINT(-73.96260947 40.80982869)
# 193175 | honeylocust | Good | Alive | POINT(-73.96300373 40.80176053)
# 218086 | honeylocust | Good | Alive | POINT(-73.96745978 40.80342043)
# 209867 | pin oak | Good | Alive | POINT(-73.96277025 40.80955855)
# 209779 | pin oak | Good | Alive | POINT(-73.96132709 40.81145199)
# 210000 | pin oak | Good | Alive | POINT(-73.96515307 40.80629396)
# 193168 | Callery pear | Good | Alive | POINT(-73.96227077 40.80145189)
# 209997 | northern red oak | Good | Alive | POINT(-73.96511473 40.80640021)
# 209869 | pin oak | Good | Alive | POINT(-73.96281509 40.80949803)
# 188600 | American elm | Good | Alive | POINT(-73.96029044 40.80431772)
# 183148 | American elm | Good | Alive | POINT(-73.95471578 40.80423757)
# 218083 | American elm | Good | Alive | POINT(-73.96763927 40.80317437)
# 214744 | Callery pear | Fair | Alive | POINT(-73.96388081 40.80771922)
# 217812 | Sophora | Good | Alive | POINT(-73.96902175 40.80276141)
# 135268 | black maple | Good | Alive | POINT(-73.95607858 40.81047273)
# 217814 | honeylocust | Good | Alive | POINT(-73.96875721 40.80264963)
# 207284 | London planetree | Fair | Alive | POINT(-73.95750449 40.80422212)
# 214753 | willow oak | Fair | Alive | POINT(-73.96275741 40.80926079)
# 217950 | littleleaf linden | Good | Alive | POINT(-73.96827804 40.8031578)
# 214755 | willow oak | Good | Alive | POINT(-73.96257017 40.80951771)
# 207283 | London planetree | Fair | Alive | POINT(-73.95757935 40.80411777)
# 214752 | willow oak | Fair | Alive | POINT(-73.96284315 40.80914313)
# 214754 | willow oak | Fair | Alive | POINT(-73.96268216 40.80936404)
# 214751 | willow oak | Fair | Alive | POINT(-73.9629009 40.80906389)
# 209783 | purple-leaf plum | Good | Alive | POINT(-73.96146422 40.81131562)
# 209784 | purple-leaf plum | Good | Alive | POINT(-73.9614341 40.81130312)
# 209782 | purple-leaf plum | Good | Alive | POINT(-73.96145625 40.8113267)
# 182995 | honeylocust | Good | Alive | POINT(-73.9545702 40.80397435)
# 217815 | honeylocust | Good | Alive | POINT(-73.96866061 40.80260881)
# 217811 | honeylocust | Good | Alive | POINT(-73.96936237 40.80290533)
# 207299 | honeylocust | Good | Alive | POINT(-73.95741629 40.80407623)
# 207149 | honeylocust | Fair | Alive | POINT(-73.95710903 40.80217513)
# 207151 | honeylocust | Fair | Alive | POINT(-73.95693548 40.80241145)
# 182993 | honeylocust | Good | Alive | POINT(-73.95479246 40.80406767)
# 190333 | None | None | Dead | POINT(-73.95712081 40.80420891)
# 222714 | honeylocust | Good | Alive | POINT(-73.96221391 40.80071455)
# 139764 | magnolia | Good | Alive | POINT(-73.95690633 40.80340872)
# 139766 | magnolia | Fair | Alive | POINT(-73.9572446 40.80355134)
# 193181 | None | None | Stump | POINT(-73.9635386 40.80198576)
# 207211 | silver linden | Fair | Alive | POINT(-73.95814007 40.80299708)
# 207262 | Callery pear | Good | Alive | POINT(-73.95800388 40.80387244)
# 193177 | Callery pear | Good | Alive | POINT(-73.96320561 40.80184554)
# 225207 | None | None | Dead | POINT(-73.958035 40.80224236)
# 209963 | pin oak | Good | Alive | POINT(-73.96466592 40.80701751)
# 188837 | Kentucky coffeetree | Fair | Alive | POINT(-73.95872391 40.80901462)
# 217813 | Sophora | Good | Alive | POINT(-73.96894251 40.80272793)
# 193173 | cherry | Good | Alive | POINT(-73.96275225 40.80165464)
# 190356 | green ash | Fair | Alive | POINT(-73.9577948 40.80449479)
# 196580 | green ash | Good | Alive | POINT(-73.96692235 40.80772711)
# 209925 | London planetree | Fair | Alive | POINT(-73.96352729 40.80857523)
# 210212 | London planetree | Fair | Alive | POINT(-73.96635636 40.80466251)
# 210216 | London planetree | Fair | Alive | POINT(-73.96651028 40.80449908)
# 209996 | None | None | Stump | POINT(-73.96506846 40.80646357)
# 210126 | crab apple | Good | Alive | POINT(-73.96545075 40.80588705)
# 210211 | London planetree | Fair | Alive | POINT(-73.9663667 40.80470312)
# 210213 | London planetree | Fair | Alive | POINT(-73.96641785 40.80457513)
# 225089 | ginkgo | Good | Alive | POINT(-73.95907904 40.80104493)
# 225084 | ginkgo | Good | Alive | POINT(-73.95859419 40.8008287)
# 225092 | ginkgo | Good | Alive | POINT(-73.95931261 40.80114253)
# 225085 | ginkgo | Good | Alive | POINT(-73.95864732 40.80085549)
# 225087 | ginkgo | Fair | Alive | POINT(-73.95883977 40.80094494)
# 203843 | maple | Poor | Alive | POINT(-73.96167834 40.80460104)
# 225024 | Sophora | Fair | Alive | POINT(-73.96475879 40.80191902)
# 210218 | cherry | Good | Alive | POINT(-73.96652993 40.80441587)
# 210130 | pin oak | Good | Alive | POINT(-73.96561324 40.80571825)
# 225027 | Sophora | Good | Alive | POINT(-73.96455582 40.80219787)
# 210215 | purple-leaf plum | Fair | Alive | POINT(-73.96649172 40.80452546)
# 210219 | cherry | Good | Alive | POINT(-73.96657024 40.80441388)
# 209930 | London planetree | Fair | Alive | POINT(-73.96365635 40.80834523)
# 76463 | Japanese tree lilac | Good | Alive | POINT(-73.96741334 40.80437853)
# 209836 | crab apple | Poor | Alive | POINT(-73.96242694 40.81008038)
# 218084 | None | None | Stump | POINT(-73.96755994 40.80328312)
# 193179 | Callery pear | Good | Alive | POINT(-73.96339011 40.80192323)
# 209838 | crab apple | Good | Alive | POINT(-73.96241965 40.81003654)
# 198535 | American elm | Good | Alive | POINT(-73.95980694 40.80138131)
# 198522 | willow oak | Fair | Alive | POINT(-73.96078837 40.80176667)
# 198532 | American elm | Good | Alive | POINT(-73.96016513 40.80153285)
# 198530 | willow oak | Good | Alive | POINT(-73.96038064 40.80159418)
# 231987 | pin oak | Good | Alive | POINT(-73.9561496 40.80484411)
# 207305 | shingle oak | Good | Alive | POINT(-73.9557357 40.80406216)
# 210131 | pin oak | Good | Alive | POINT(-73.96565583 40.80565993)
# 76464 | Japanese tree lilac | Good | Alive | POINT(-73.9673648 40.80435788)
# 222716 | None | None | Dead | POINT(-73.96335275 40.80119482)
# 198526 | American elm | Good | Alive | POINT(-73.96055266 40.8016968)
# 232016 | willow oak | Fair | Alive | POINT(-73.95600737 40.80457947)
# 198523 | willow oak | Poor | Alive | POINT(-73.96070411 40.80173103)
# 187705 | honeylocust | Good | Alive | POINT(-73.95391003 40.80656162)
# 187709 | honeylocust | Good | Alive | POINT(-73.95370588 40.80684343)
# 232013 | pin oak | Good | Alive | POINT(-73.95646291 40.80477139)
# 214709 | pin oak | Fair | Alive | POINT(-73.96493688 40.80627157)
# 214711 | pin oak | Fair | Alive | POINT(-73.96480552 40.80644846)
# 232015 | pin oak | Good | Alive | POINT(-73.95609793 40.80458781)
# 214707 | pin oak | Fair | Alive | POINT(-73.96502032 40.80615922)
# 188999 | honeylocust | Good | Alive | POINT(-73.95912544 40.80858195)
# 247580 | Japanese zelkova | Good | Alive | POINT(-73.9562875 40.80396884)
# 189000 | honeylocust | Good | Alive | POINT(-73.95931797 40.80866339)
# 225210 | American linden | Fair | Alive | POINT(-73.95832957 40.80282441)
# 188997 | golden raintree | Good | Alive | POINT(-73.95889283 40.80848355)
# 225211 | American linden | Fair | Alive | POINT(-73.95827902 40.80289413)
# 222723 | honeylocust | Good | Alive | POINT(-73.9644755 40.80166829)
# 198520 | London planetree | Fair | Alive | POINT(-73.96133176 40.80198651)
# 240339 | ginkgo | Good | Alive | POINT(-73.95974013 40.80790803)
# 217549 | honeylocust | Good | Alive | POINT(-73.96815272 40.80155763)
# 240647 | American linden | Good | Alive | POINT(-73.95974356 40.80842575)
# 211610 | Chinese elm | Good | Alive | POINT(-73.96416 40.80270875)
# 211612 | Chinese elm | Good | Alive | POINT(-73.96409471 40.80280948)
# 240648 | littleleaf linden | Poor | Alive | POINT(-73.95967006 40.80853035)
# 231990 | Sophora | Good | Alive | POINT(-73.95653477 40.80500625)
# 211607 | ginkgo | Good | Alive | POINT(-73.96432173 40.80250433)
# 247585 | honeylocust | Good | Alive | POINT(-73.95738638 40.80536574)
# 210128 | pin oak | Good | Alive | POINT(-73.96549544 40.80582585)
# 247705 | London planetree | Fair | Alive | POINT(-73.95818176 40.80488906)
# 139763 | magnolia | Good | Alive | POINT(-73.95670419 40.8033235)
# 139765 | magnolia | Good | Alive | POINT(-73.95707215 40.80347864)
# 225162 | Sophora | Good | Alive | POINT(-73.95789918 40.80136473)
# 247609 | London planetree | Good | Alive | POINT(-73.95522178 40.80734716)
# 225166 | Japanese zelkova | Good | Alive | POINT(-73.95883448 40.80175889)
# 225097 | northern red oak | Fair | Alive | POINT(-73.95858405 40.80154447)
# 211613 | Chinese elm | Poor | Alive | POINT(-73.96401355 40.80283128)
# 225099 | northern red oak | Good | Alive | POINT(-73.95837288 40.80145578)
# 247583 | None | None | Dead | POINT(-73.95782861 40.80555213)
# 225096 | Chinese elm | Good | Alive | POINT(-73.95877625 40.80162519)
# 196587 | green ash | Good | Alive | POINT(-73.96708925 40.8071505)
# 225098 | northern red oak | Good | Alive | POINT(-73.95850628 40.80151181)
# 225100 | northern red oak | Good | Alive | POINT(-73.95826919 40.80141223)
# 247574 | honeylocust | Fair | Alive | POINT(-73.95702423 40.80427914)
# 225201 | American linden | Good | Alive | POINT(-73.95769224 40.80198519)
# 247581 | honeylocust | Good | Alive | POINT(-73.95619904 40.80393158)
# 255376 | honeylocust | Fair | Alive | POINT(-73.96317822 40.80429848)
# 225045 | Sophora | Good | Alive | POINT(-73.96171615 40.80099025)
# 247870 | honeylocust | Good | Alive | POINT(-73.95720984 40.80612987)
# 255385 | ginkgo | Poor | Alive | POINT(-73.96404933 40.8046669)
# 255092 | American linden | Fair | Alive | POINT(-73.96448437 40.80496089)
# 247868 | honeylocust | Good | Alive | POINT(-73.95741135 40.8062154)
# 255384 | ginkgo | Fair | Alive | POINT(-73.9639357 40.80461884)
# 255095 | American linden | Fair | Alive | POINT(-73.96424427 40.80485974)
# 261733 | ginkgo | Good | Alive | POINT(-73.96235372 40.81242157)
# 247676 | ginkgo | Good | Alive | POINT(-73.95814907 40.80447083)
# 255087 | ginkgo | Fair | Alive | POINT(-73.96540367 40.80534816)
# 255088 | ginkgo | Fair | Alive | POINT(-73.96512567 40.80523105)
# 261736 | ginkgo | Good | Alive | POINT(-73.96273867 40.81258463)
# 255389 | ginkgo | Poor | Alive | POINT(-73.96442807 40.80482708)
# 255390 | ginkgo | Poor | Alive | POINT(-73.96448173 40.80484977)
# 261732 | ginkgo | Fair | Alive | POINT(-73.96222309 40.81236624)
# 261734 | ginkgo | Good | Alive | POINT(-73.96248057 40.8124753)
# 247601 | pin oak | Good | Alive | POINT(-73.95531603 40.80615259)
# 247604 | pin oak | Good | Alive | POINT(-73.95555757 40.80625402)
# 255393 | mulberry | Good | Alive | POINT(-73.96475947 40.80496723)
# 255400 | Callery pear | Good | Alive | POINT(-73.96550435 40.80528224)
# 255397 | Callery pear | Poor | Alive | POINT(-73.96514453 40.80513008)
# 261914 | Japanese zelkova | Good | Alive | POINT(-73.96096629 40.81232302)
# 225043 | Sophora | Good | Alive | POINT(-73.96178787 40.80089242)
# 240569 | Sophora | Good | Alive | POINT(-73.96006269 40.80797886)
# 247677 | ginkgo | Good | Alive | POINT(-73.9581531 40.80453718)
# 261917 | ginkgo | Poor | Alive | POINT(-73.96065889 40.81274274)
# 211830 | None | None | Dead | POINT(-73.96763893 40.80197973)
# 247673 | swamp white oak | Good | Alive | POINT(-73.95812896 40.80413962)
# 203996 | Callery pear | Good | Alive | POINT(-73.96134249 40.80528416)
# 189414 | ginkgo | Good | Alive | POINT(-73.95983152 40.80805619)
# 209822 | pin oak | Good | Alive | POINT(-73.96178527 40.81096414)
# 193113 | honeylocust | Good | Alive | POINT(-73.96485891 40.80254091)
# 188546 | London planetree | Good | Alive | POINT(-73.96103563 40.8021517)
# 188545 | London planetree | Good | Alive | POINT(-73.96106765 40.80205905)
# 139761 | magnolia | Good | Alive | POINT(-73.9565131 40.80324293)
# 209831 | None | None | Stump | POINT(-73.96229489 40.8102617)
# 188667 | northern red oak | Good | Alive | POINT(-73.95913037 40.80654817)
# 193106 | honeylocust | Good | Alive | POINT(-73.96564922 40.80287511)
# 209862 | pin oak | Poor | Alive | POINT(-73.96268071 40.80973254)
# 209998 | pin oak | Good | Alive | POINT(-73.96510628 40.80635804)
# 209780 | pin oak | Good | Alive | POINT(-73.96137902 40.81143414)
# 209923 | white oak | Good | Alive | POINT(-73.9634834 40.8086352)
# 210162 | London planetree | Fair | Alive | POINT(-73.9659669 40.80523575)
# 190325 | American elm | Good | Alive | POINT(-73.95617734 40.80381403)
# 190332 | American elm | Good | Alive | POINT(-73.95700881 40.80416204)
# 182932 | Japanese zelkova | Good | Alive | POINT(-73.95486513 40.80337213)
# 182934 | Japanese zelkova | Good | Alive | POINT(-73.95523023 40.80352608)
# 210003 | crab apple | Good | Alive | POINT(-73.96525108 40.80621349)
# 217948 | honeylocust | Good | Alive | POINT(-73.96809468 40.8030808)
# 218085 | honeylocust | Good | Alive | POINT(-73.96750146 40.8033633)
# 196537 | honeylocust | Good | Alive | POINT(-73.96522509 40.80967202)
# 182937 | Chinese elm | Good | Alive | POINT(-73.95555965 40.80366499)
# 217954 | honeylocust | Good | Alive | POINT(-73.96891064 40.80342344)
# 210166 | London planetree | Poor | Alive | POINT(-73.96607025 40.80509256)
# 209860 | crab apple | Poor | Alive | POINT(-73.96264314 40.80978325)
# 210169 | London planetree | Good | Alive | POINT(-73.96610409 40.80499146)
# 209825 | pin oak | Fair | Alive | POINT(-73.96184226 40.81083189)
# 209864 | pin oak | Good | Alive | POINT(-73.96273175 40.80966366)
# 209827 | pin oak | Good | Alive | POINT(-73.96190884 40.81074037)
# 209995 | pin oak | Good | Alive | POINT(-73.96502255 40.80652645)
# 209861 | pin oak | Good | Alive | POINT(-73.96263752 40.80973769)
# 207247 | Callery pear | Fair | Alive | POINT(-73.95792265 40.8037238)
# 209994 | None | None | Dead | POINT(-73.96499254 40.8065138)
# 214749 | London planetree | Fair | Alive | POINT(-73.96307414 40.80882617)
# 209865 | None | None | Dead | POINT(-73.96272595 40.80961834)
# 210168 | London planetree | Poor | Alive | POINT(-73.96611038 40.80503697)
# 209775 | crab apple | Poor | Alive | POINT(-73.96125695 40.81160396)
# 196539 | honeylocust | Good | Alive | POINT(-73.96539242 40.80943997)
# 188599 | American elm | Good | Alive | POINT(-73.96031734 40.80423795)
# 210001 | crab apple | Good | Alive | POINT(-73.96522742 40.80624589)
# 188598 | American elm | Good | Alive | POINT(-73.9603697 40.80408268)
# 188602 | American elm | Good | Alive | POINT(-73.96021091 40.80455355)
# 218082 | American elm | Fair | Alive | POINT(-73.96768848 40.80310691)
# 183147 | American elm | Good | Alive | POINT(-73.95456553 40.80417406)
# 210125 | crab apple | Good | Alive | POINT(-73.96546726 40.80591818)
# 207148 | honeylocust | Fair | Alive | POINT(-73.95717327 40.80208764)
# 209778 | northern red oak | Good | Alive | POINT(-73.96130804 40.81147849)
# 210123 | crab apple | Good | Alive | POINT(-73.96542253 40.80592569)
# 207246 | London planetree | Fair | Alive | POINT(-73.95806787 40.80378049)
# 188601 | American elm | Good | Alive | POINT(-73.96026426 40.80439535)
# 214742 | ginkgo | Poor | Alive | POINT(-73.96411003 40.80740466)
# 209772 | None | None | Dead | POINT(-73.96119756 40.81163217)
# 188671 | Callery pear | Good | Alive | POINT(-73.95872645 40.80710234)
# 214743 | Callery pear | Fair | Alive | POINT(-73.96393505 40.80764478)
# 188672 | Callery pear | Good | Alive | POINT(-73.95865644 40.80719838)
# 207300 | None | None | Stump | POINT(-73.9575287 40.80392273)
# 196586 | sweetgum | Poor | Alive | POINT(-73.96706368 40.80721344)
# 209868 | None | None | Dead | POINT(-73.96281185 40.80955555)
# 203841 | common hackberry | Fair | Alive | POINT(-73.96219406 40.80481916)
# 188844 | None | None | Dead | POINT(-73.95792008 40.80867168)
# 225204 | Sophora | Good | Alive | POINT(-73.95760107 40.80205878)
# 189404 | red maple | Fair | Alive | POINT(-73.95871626 40.80758534)
# 209917 | pin oak | Good | Alive | POINT(-73.96329537 40.8088921)
# 210157 | magnolia | Good | Alive | POINT(-73.96589343 40.80533754)
# 207304 | shingle oak | Fair | Alive | POINT(-73.95577149 40.8040129)
# 182991 | Sophora | Fair | Alive | POINT(-73.95505518 40.80417799)
# 196542 | honeylocust | Good | Alive | POINT(-73.96560453 40.80914583)
# 209781 | purple-leaf plum | Poor | Alive | POINT(-73.96142059 40.81132191)
# 207095 | ginkgo | Fair | Alive | POINT(-73.95830106 40.80089816)
# 209771 | cherry | Good | Alive | POINT(-73.96122768 40.81164467)
# 207298 | London planetree | Fair | Alive | POINT(-73.9573557 40.80415897)
# 207204 | honeylocust | Good | Alive | POINT(-73.95699539 40.80251515)
# 207297 | honeylocust | Good | Alive | POINT(-73.95712953 40.80447258)
# 217817 | honeylocust | Good | Alive | POINT(-73.96836166 40.8024825)
# 182994 | honeylocust | Good | Alive | POINT(-73.95469982 40.80402878)
# 182996 | pin oak | Good | Alive | POINT(-73.95449464 40.80394262)
# 225209 | American linden | Good | Alive | POINT(-73.95833386 40.8023688)
# 182992 | honeylocust | Good | Alive | POINT(-73.95488793 40.80410776)
# 207255 | London planetree | Poor | Alive | POINT(-73.95797804 40.80357125)
# 207230 | London planetree | Good | Alive | POINT(-73.95814093 40.80361378)
# 207296 | honeylocust | Good | Alive | POINT(-73.95704572 40.80458728)
# 203848 | common hackberry | Fair | Alive | POINT(-73.96051435 40.80410874)
# 188845 | Sophora | Good | Alive | POINT(-73.95784417 40.8086393)
# 225205 | Sophora | Good | Alive | POINT(-73.9576806 40.80209243)
# 188670 | Callery pear | Good | Alive | POINT(-73.9587926 40.80701158)
# 188998 | black locust | Fair | Alive | POINT(-73.95903643 40.8085443)
# 207263 | Callery pear | Good | Alive | POINT(-73.95792224 40.80383829)
# 209964 | pin oak | Fair | Alive | POINT(-73.9646534 40.80698045)
# 209960 | None | None | Stump | POINT(-73.96457143 40.80714937)
# 225093 | None | None | Stump | POINT(-73.95937876 40.80117018)
# 190355 | common hackberry | Good | Alive | POINT(-73.95752313 40.80438033)
# 209928 | London planetree | Fair | Alive | POINT(-73.96361507 40.80845529)
# 209924 | London planetree | Poor | Alive | POINT(-73.96347342 40.80859518)
# 190358 | green ash | Fair | Alive | POINT(-73.95801656 40.80458822)
# 183145 | honeylocust | Fair | Alive | POINT(-73.95425904 40.80404449)
# 214750 | sawtooth oak | Fair | Alive | POINT(-73.96295339 40.80899185)
# 225025 | Sophora | Good | Alive | POINT(-73.96469673 40.80200429)
# 210127 | pin oak | Good | Alive | POINT(-73.96550354 40.8058685)
# 210129 | pin oak | Good | Alive | POINT(-73.96554752 40.80580826)
# 232012 | pin oak | Good | Alive | POINT(-73.95665182 40.80485098)
# 210217 | London planetree | Fair | Alive | POINT(-73.96653924 40.80445793)
# 210214 | London planetree | Fair | Alive | POINT(-73.96646872 40.80455814)
# 210136 | crab apple | Good | Alive | POINT(-73.96572716 40.80556225)
# 222715 | green ash | Good | Alive | POINT(-73.96232287 40.8007605)
# 193178 | Callery pear | Good | Alive | POINT(-73.96330734 40.80188838)
# 198524 | American elm | Good | Alive | POINT(-73.96067732 40.80174954)
# 198531 | willow oak | Good | Alive | POINT(-73.9603049 40.80156214)
# 198536 | American elm | Fair | Alive | POINT(-73.95972678 40.8013474)
# 222753 | honeylocust | Good | Alive | POINT(-73.96450812 40.80189765)
# 139762 | magnolia | Good | Alive | POINT(-73.95661512 40.80328595)
# 209965 | pin oak | Good | Alive | POINT(-73.96469677 40.80691995)
# 209966 | pin oak | Good | Alive | POINT(-73.96474625 40.80690542)
# 211530 | American linden | Fair | Alive | POINT(-73.96723047 40.80313278)
# 187706 | honeylocust | Good | Alive | POINT(-73.95386196 40.80662798)
# 209967 | pin oak | Good | Alive | POINT(-73.96473823 40.8068621)
# 231988 | pin oak | Good | Alive | POINT(-73.95630759 40.80491062)
# 247597 | pin oak | Good | Alive | POINT(-73.95503307 40.80603376)
# 232014 | pin oak | Good | Alive | POINT(-73.95627336 40.80469154)
# 222718 | honeylocust | Good | Alive | POINT(-73.96372447 40.80135158)
# 240333 | honeylocust | Good | Alive | POINT(-73.95868135 40.80745941)
# 211608 | Callery pear | Good | Alive | POINT(-73.96425696 40.80258619)
# 240334 | honeylocust | Good | Alive | POINT(-73.95878609 40.80750379)
# 207295 | Callery pear | Good | Alive | POINT(-73.95722618 40.80460094)
# 247578 | pin oak | Good | Alive | POINT(-73.95646631 40.80404415)
# 240336 | ginkgo | Good | Alive | POINT(-73.95939246 40.80776072)
# 240338 | ginkgo | Good | Alive | POINT(-73.95961393 40.80785456)
# 217548 | honeylocust | Good | Alive | POINT(-73.96821946 40.801582)
# 240340 | American linden | Poor | Alive | POINT(-73.95986696 40.80796177)
# 247696 | honeylocust | Good | Alive | POINT(-73.95606628 40.80646659)
# 247584 | honeylocust | Good | Alive | POINT(-73.95771552 40.80550447)
# 247582 | honeylocust | Good | Alive | POINT(-73.95792653 40.8055934)
# 214746 | honeylocust | Fair | Alive | POINT(-73.96334711 40.80845158)
# 247769 | Japanese zelkova | Good | Alive | POINT(-73.95805203 40.80544538)
# 247773 | ginkgo | Poor | Alive | POINT(-73.95771454 40.80530224)
# 247579 | London planetree | Fair | Alive | POINT(-73.956369 40.80400317)
# 198521 | American elm | Good | Alive | POINT(-73.96079377 40.8017988)
# 198528 | willow oak | Good | Alive | POINT(-73.96045606 40.80162609)
# 247527 | Callery pear | Good | Alive | POINT(-73.95610323 40.80801744)
# 225041 | Callery pear | Poor | Alive | POINT(-73.96193025 40.80069821)
# 247770 | ginkgo | Good | Alive | POINT(-73.95797885 40.80541434)
# 225044 | Sophora | Good | Alive | POINT(-73.96175166 40.80094182)
# 247596 | pin oak | Fair | Alive | POINT(-73.95496858 40.80600668)
# 214708 | pin oak | Fair | Alive | POINT(-73.96497416 40.80622137)
# 240567 | Sophora | Good | Alive | POINT(-73.96024484 40.80773361)
# 247663 | honeylocust | Good | Alive | POINT(-73.95652006 40.80556151)
# 225198 | American linden | Good | Alive | POINT(-73.9580801 40.8021487)
# 225200 | American linden | Good | Alive | POINT(-73.9577592 40.80201342)
# 247779 | ginkgo | Fair | Alive | POINT(-73.95638932 40.80548)
# 240568 | Sophora | Good | Alive | POINT(-73.96017986 40.8078211)
# 222720 | Sophora | Good | Alive | POINT(-73.96399735 40.80146665)
# 240337 | ginkgo | Fair | Alive | POINT(-73.95950288 40.80780751)
# 247784 | honeylocust | Good | Alive | POINT(-73.95749757 40.8063981)
# 207208 | golden raintree | Good | Alive | POINT(-73.95766993 40.80279915)
# 247660 | honeylocust | Good | Alive | POINT(-73.956706 40.80530907)
# 247778 | ginkgo | Good | Alive | POINT(-73.95643847 40.80541283)
# 255378 | honeylocust | Fair | Alive | POINT(-73.96343072 40.80440527)
# 255101 | honeylocust | Good | Alive | POINT(-73.96321126 40.80442454)
# 255102 | honeylocust | Good | Alive | POINT(-73.9631386 40.80439393)
# 255093 | ginkgo | Poor | Alive | POINT(-73.96441171 40.80493028)
# 247869 | honeylocust | Good | Alive | POINT(-73.95729971 40.80616801)
# 247659 | honeylocust | Fair | Alive | POINT(-73.95675398 40.80524392)
# 255381 | honeylocust | Good | Alive | POINT(-73.96369268 40.80451606)
# 255398 | ginkgo | Poor | Alive | POINT(-73.96533075 40.80520883)
# 247605 | Sophora | Good | Alive | POINT(-73.95563028 40.80628455)
# 247783 | honeylocust | Good | Alive | POINT(-73.95745349 40.80645893)
# 255089 | ginkgo | Fair | Alive | POINT(-73.96500878 40.80518181)
# 255090 | ginkgo | Poor | Alive | POINT(-73.96491084 40.80514055)
# 240669 | honeylocust | Good | Alive | POINT(-73.95930258 40.80903293)
# 247675 | None | None | Stump | POINT(-73.95814114 40.80434032)
# 255399 | ginkgo | Good | Alive | POINT(-73.9654286 40.80525021)
# 255096 | ginkgo | Poor | Alive | POINT(-73.96417161 40.80482913)
# 255097 | honeylocust | Fair | Alive | POINT(-73.96357455 40.80457759)
# 247603 | pin oak | Good | Alive | POINT(-73.955476 40.80621976)
# 225196 | littleleaf linden | Poor | Alive | POINT(-73.95849703 40.80232446)
# 211826 | ginkgo | Fair | Alive | POINT(-73.96765911 40.80168562)
# 261748 | ginkgo | Good | Alive | POINT(-73.96007015 40.81398893)
# 188717 | swamp white oak | Good | Alive | POINT(-73.95789547 40.80828717)
# 138432 | Siberian elm | Good | Alive | POINT(-73.96012385 40.804327)
# 218308 | honeylocust | Good | Alive | POINT(-73.96743808 40.80363064)
# 218306 | honeylocust | Good | Alive | POINT(-73.96762932 40.803711)
# 218233 | honeylocust | Good | Alive | POINT(-73.96717136 40.80527321)
# 225101 | swamp white oak | Good | Alive | POINT(-73.95804695 40.8013189)
# 193165 | common hackberry | Fair | Alive | POINT(-73.96198359 40.80133096)
# 225102 | swamp white oak | Good | Alive | POINT(-73.95795559 40.80128053)
# 211829 | American elm | Poor | Alive | POINT(-73.96764267 40.80192518)
# 271118 | Chinese elm | Good | Alive | POINT(-73.95520931 40.80531813)
# 261920 | ginkgo | Fair | Alive | POINT(-73.96046127 40.81301256)
# 261924 | honeylocust | Good | Alive | POINT(-73.96014332 40.81344667)
# 270981 | American hophornbeam | Good | Alive | POINT(-73.95625759 40.8064366)
# 270982 | silver linden | Good | Alive | POINT(-73.95652765 40.8065499)
# 271032 | silver linden | Poor | Alive | POINT(-73.95600846 40.80600026)
# 271031 | silver linden | Fair | Alive | POINT(-73.9559649 40.80606036)
# 247738 | Callery pear | Good | Alive | POINT(-73.95703794 40.80594467)
# 247740 | Callery pear | Good | Alive | POINT(-73.95724521 40.80603193)
# 247873 | Callery pear | Good | Alive | POINT(-73.95678095 40.80594784)
# 247710 | Japanese zelkova | Good | Alive | POINT(-73.95816525 40.80540337)
# 247929 | Japanese zelkova | Good | Alive | POINT(-73.95468468 40.80742358)
# 270985 | honeylocust | Good | Alive | POINT(-73.95707789 40.80678073)
# 211487 | ginkgo | Good | Alive | POINT(-73.96557276 40.80079478)
# 270984 | honeylocust | Good | Alive | POINT(-73.9569808 40.80674)
# 271119 | Chinese elm | Fair | Alive | POINT(-73.95512762 40.80528404)
# 255098 | black locust | Fair | Alive | POINT(-73.96347662 40.80453634)
# 261816 | None | None | Dead | POINT(-73.96132939 40.81317244)
# 247978 | Japanese zelkova | Good | Alive | POINT(-73.95523981 40.80706198)
# 211486 | American elm | Fair | Alive | POINT(-73.96566073 40.80067493)
# 247872 | American elm | Good | Alive | POINT(-73.95697521 40.80603029)
# 211825 | ginkgo | Good | Alive | POINT(-73.96766379 40.80161737)
# 247701 | honeylocust | Good | Alive | POINT(-73.95665632 40.80671477)
# 261974 | ginkgo | Good | Alive | POINT(-73.9604749 40.81401106)
# 247697 | honeylocust | Good | Alive | POINT(-73.95616425 40.8065078)
# 247699 | honeylocust | Good | Alive | POINT(-73.95647618 40.806639)
# 218188 | Sophora | Good | Alive | POINT(-73.96626305 40.80506215)
# 210170 | magnolia | Good | Alive | POINT(-73.96612632 40.80496066)
# 139769 | magnolia | Good | Alive | POINT(-73.95757498 40.80369063)
# 139708 | paper birch | Poor | Alive | POINT(-73.95755943 40.80286321)
# 261809 | ginkgo | Good | Alive | POINT(-73.96081328 40.81387771)
# 218229 | Sophora | Good | Alive | POINT(-73.96684146 40.80513326)
# 218231 | Sophora | Fair | Alive | POINT(-73.96701555 40.80520712)
# 247450 | Sophora | Good | Alive | POINT(-73.95765041 40.80454457)
# 139768 | magnolia | Good | Alive | POINT(-73.95747012 40.80364642)
# 247931 | katsura tree | Fair | Alive | POINT(-73.95619696 40.80601083)
# 214760 | bald cypress | Good | Alive | POINT(-73.96222719 40.80998835)
# 217816 | shingle oak | Good | Alive | POINT(-73.96847909 40.80253212)
# 247658 | honeylocust | Good | Alive | POINT(-73.95587085 40.80645227)
# 261813 | ginkgo | Good | Alive | POINT(-73.9610845 40.81350708)
# 247833 | pin oak | Good | Alive | POINT(-73.95688821 40.80723538)
# 247923 | honeylocust | Good | Alive | POINT(-73.95375786 40.80702848)
# 247526 | honeylocust | Good | Alive | POINT(-73.95799089 40.8057249)
# 281728 | honeylocust | Good | Alive | POINT(-73.96628984 40.80150762)
# 247834 | honeylocust | Good | Alive | POINT(-73.95699828 40.80708592)
# 247975 | Japanese zelkova | Good | Alive | POINT(-73.95507175 40.80729121)
# 281720 | American linden | Good | Alive | POINT(-73.96544245 40.80115091)
# 270970 | littleleaf linden | Good | Alive | POINT(-73.95489812 40.80586452)
# 247533 | London planetree | Fair | Alive | POINT(-73.95520907 40.8076398)
# 281733 | None | None | Stump | POINT(-73.96686362 40.80174915)
# 207306 | shingle oak | Fair | Alive | POINT(-73.95569223 40.80412199)
# 281794 | None | None | Dead | POINT(-73.96632277 40.80234147)
# 281797 | None | None | Stump | POINT(-73.96579139 40.80211769)
# 271117 | American hophornbeam | Good | Alive | POINT(-73.95532714 40.80533757)
# 255380 | black maple | Fair | Alive | POINT(-73.96364849 40.80449738)
# 247599 | green ash | Good | Alive | POINT(-73.95517313 40.80609258)
# 255099 | black locust | Fair | Alive | POINT(-73.96342923 40.80451637)
# 278993 | ginkgo | Good | Alive | POINT(-73.95541464 40.80681527)
# 187022 | shingle oak | Good | Alive | POINT(-73.96331614 40.80389351)
# 281804 | pin oak | Good | Alive | POINT(-73.9652619 40.8018947)
# 218302 | Sophora | Fair | Alive | POINT(-73.96840976 40.80403895)
# 218234 | Sophora | Poor | Alive | POINT(-73.96726629 40.80531349)
# 261641 | Callery pear | Good | Alive | POINT(-73.95957011 40.81423553)
# 270969 | honeylocust | Good | Alive | POINT(-73.95480118 40.80582417)
# 217903 | pin oak | Good | Alive | POINT(-73.96813502 40.80246081)
# 278994 | pin oak | Good | Alive | POINT(-73.95546144 40.80675151)
# 281803 | pin oak | Good | Alive | POINT(-73.96533835 40.80192689)
# 217907 | honeylocust | Good | Alive | POINT(-73.96783693 40.80287344)
# 247878 | honeylocust | Fair | Alive | POINT(-73.95592668 40.80547564)
# 247657 | honeylocust | Good | Alive | POINT(-73.95582829 40.80651092)
# 281808 | Sophora | Fair | Alive | POINT(-73.96495166 40.80176404)
# 281792 | Sophora | Good | Alive | POINT(-73.96648706 40.80241066)
# 247883 | honeylocust | Fair | Alive | POINT(-73.95545424 40.80527745)
# 217906 | crab apple | Good | Alive | POINT(-73.96794018 40.80273052)
# 247775 | honeylocust | Good | Alive | POINT(-73.95733163 40.80513984)
# 247612 | green ash | Good | Alive | POINT(-73.95537944 40.80713112)
# 281805 | littleleaf linden | Fair | Alive | POINT(-73.96519492 40.80186649)
# 281962 | Kentucky coffeetree | Good | Alive | POINT(-73.96568376 40.80525451)
# 281730 | Sophora | Good | Alive | POINT(-73.96647879 40.80158715)
# 278997 | cherry | Fair | Alive | POINT(-73.95560201 40.80655997)
# 247928 | cherry | Fair | Alive | POINT(-73.95436838 40.80728875)
# 247925 | honeylocust | Good | Alive | POINT(-73.95411132 40.80717916)
# 281985 | pin oak | Good | Alive | POINT(-73.96529769 40.80578119)
# 281891 | honeylocust | Good | Alive | POINT(-73.96673745 40.80261787)
# 281892 | Sophora | Good | Alive | POINT(-73.96681519 40.80265057)
# 281890 | ginkgo | Good | Alive | POINT(-73.96666066 40.80258556)
# 247576 | Kentucky coffeetree | Good | Alive | POINT(-73.95683784 40.80420063)
# 281889 | honeylocust | Good | Alive | POINT(-73.96657345 40.80254887)
# 281888 | honeylocust | Good | Alive | POINT(-73.96645937 40.80250087)
# 281960 | Callery pear | Good | Alive | POINT(-73.96576654 40.80514063)
# 281894 | Sophora | Good | Alive | POINT(-73.96705314 40.80275068)
# 281886 | honeylocust | Good | Alive | POINT(-73.96610798 40.80235303)
# 270971 | littleleaf linden | Good | Alive | POINT(-73.95499253 40.80590381)
# ...
# 188551 | London planetree | Good | Alive | POINT(-73.96080159 40.80282891)
# 188553 | London planetree | Good | Alive | POINT(-73.96070645 40.8031042)
# 188716 | American elm | Fair | Alive | POINT(-73.9579428 40.80819544)
# 189183 | ginkgo | Good | Alive | POINT(-73.95858939 40.80824407)
# 188557 | London planetree | Good | Alive | POINT(-73.96056368 40.80351728)
# 188550 | swamp white oak | Good | Alive | POINT(-73.96083627 40.80272856)
# 186771 | Callery pear | Good | Alive | POINT(-73.96408058 40.80316222)
# 186918 | honeylocust | Good | Alive | POINT(-73.96574117 40.80455779)
# 188556 | London planetree | Good | Alive | POINT(-73.96059873 40.80341587)
# 186929 | honeylocust | Good | Alive | POINT(-73.96392853 40.8037958)
# 135346 | black maple | Good | Alive | POINT(-73.95538132 40.81028771)
# 186925 | honeylocust | Good | Alive | POINT(-73.96466591 40.80410578)
# 186930 | honeylocust | Good | Alive | POINT(-73.96376924 40.80372883)
# 186931 | honeylocust | Good | Alive | POINT(-73.96366873 40.80368658)
# 193100 | None | None | Stump | POINT(-73.96633003 40.80316299)
# 188696 | American elm | Fair | Alive | POINT(-73.95813958 40.80790111)
# 135492 | Sophora | Good | Alive | POINT(-73.96081817 40.81162707)
# 186919 | swamp white oak | Good | Alive | POINT(-73.96560463 40.8045004)
# 188991 | ginkgo | Fair | Alive | POINT(-73.95818206 40.80818289)
# 187148 | honeylocust | Good | Alive | POINT(-73.96143354 40.806476)
# 187147 | honeylocust | Good | Alive | POINT(-73.96152237 40.80635431)
# 187153 | honeylocust | Good | Alive | POINT(-73.95990233 40.80857355)
# 187154 | honeylocust | Good | Alive | POINT(-73.95984959 40.80864579)
# 178566 | Callery pear | Good | Alive | POINT(-73.95536854 40.8096871)
# 198505 | pin oak | Good | Alive | POINT(-73.96338472 40.80284982)
# 186779 | honeylocust | Good | Alive | POINT(-73.96503542 40.80356359)
# 186788 | ginkgo | Good | Alive | POINT(-73.96626905 40.80408213)
# 204102 | honeylocust | Good | Alive | POINT(-73.96165459 40.8057895)
# 186789 | ginkgo | Good | Alive | POINT(-73.96633325 40.80410489)
# 204100 | honeylocust | Good | Alive | POINT(-73.96154703 40.80593058)
# 178551 | Callery pear | Good | Alive | POINT(-73.9571736 40.80721218)
# 203951 | honeylocust | Good | Alive | POINT(-73.96107442 40.80656578)
# 198517 | London planetree | Fair | Alive | POINT(-73.96161492 40.80210559)
# 135440 | black cherry | Good | Alive | POINT(-73.95418857 40.80978437)
# 188995 | None | None | Dead | POINT(-73.95854502 40.80833643)
# 198507 | pin oak | Good | Alive | POINT(-73.96299915 40.80268769)
# 203884 | willow oak | Good | Alive | POINT(-73.96043246 40.80560594)
# 198504 | pin oak | Good | Alive | POINT(-73.96349849 40.80289767)
# 198506 | pin oak | Good | Alive | POINT(-73.96315654 40.80275387)
# 204077 | Callery pear | Fair | Alive | POINT(-73.96139788 40.80518753)
# 188996 | None | None | Stump | POINT(-73.9586236 40.80836967)
# 204078 | Callery pear | Good | Alive | POINT(-73.9614955 40.80522808)
# 142372 | hawthorn | Good | Alive | POINT(-73.96704423 40.80371461)
# 186777 | honeylocust | Good | Alive | POINT(-73.96483914 40.80348108)
# 203886 | willow oak | Good | Alive | POINT(-73.9606236 40.80568587)
# 203885 | willow oak | Fair | Alive | POINT(-73.96052803 40.80564591)
# 138446 | American elm | Fair | Alive | POINT(-73.96065506 40.80276468)
# 135349 | American elm | Good | Alive | POINT(-73.95600336 40.81055036)
# 135267 | Amur maple | Good | Alive | POINT(-73.95631864 40.81057395)
# 140841 | honeylocust | Fair | Alive | POINT(-73.96714533 40.80113098)
# 139707 | American elm | Fair | Alive | POINT(-73.95729276 40.80278103)
# 139709 | Callery pear | Fair | Alive | POINT(-73.95763594 40.80289533)
# 116695 | honeylocust | Good | Alive | POINT(-73.96012878 40.81229285)
# 135318 | ginkgo | Good | Alive | POINT(-73.95851021 40.80996588)
# 142362 | ginkgo | Good | Alive | POINT(-73.96695331 40.80389578)
# 142498 | crab apple | Good | Alive | POINT(-73.96782921 40.80201572)
# 139718 | None | None | Dead | POINT(-73.95783439 40.80350263)
# 140837 | honeylocust | Good | Alive | POINT(-73.9667023 40.8009446)
# 142407 | crab apple | Good | Alive | POINT(-73.96735607 40.80333709)
# 142364 | crab apple | Good | Alive | POINT(-73.96695085 40.80384474)
# 139746 | kousa dogwood | Good | Alive | POINT(-73.95675969 40.80323884)
# 104295 | sawtooth oak | Fair | Alive | POINT(-73.95416291 40.80590834)
# 142506 | ginkgo | Good | Alive | POINT(-73.967863 40.80166534)
# 142502 | ginkgo | Good | Alive | POINT(-73.96784188 40.80188433)
# 142411 | American elm | Good | Alive | POINT(-73.96742201 40.80319118)
# 142408 | American elm | Good | Alive | POINT(-73.96738554 40.80329616)
# 142410 | American elm | Good | Alive | POINT(-73.96743027 40.80323403)
# 142508 | American elm | Good | Alive | POINT(-73.96786939 40.80159909)
# 122005 | American hophornbeam | Good | Alive | POINT(-73.96479856 40.80097989)
# 135215 | Callery pear | Good | Alive | POINT(-73.96007727 40.80980262)
# 135214 | Callery pear | Good | Alive | POINT(-73.96019101 40.80985052)
# 135216 | Callery pear | Good | Alive | POINT(-73.95994141 40.8097454)
# 122010 | London planetree | Good | Alive | POINT(-73.96380468 40.80059196)
# 122008 | London planetree | Fair | Alive | POINT(-73.96400569 40.80067645)
# 142366 | London planetree | Good | Alive | POINT(-73.96700346 40.8038259)
# 122011 | London planetree | Good | Alive | POINT(-73.96370354 40.80054945)
# 142360 | London planetree | Good | Alive | POINT(-73.96692357 40.80393723)
# 135221 | Callery pear | Good | Alive | POINT(-73.95932848 40.80948724)
# 121385 | Callery pear | Fair | Alive | POINT(-73.96154279 40.8008633)
# 122009 | pin oak | Good | Alive | POINT(-73.96390329 40.80063341)
# 98862 | littleleaf linden | Fair | Alive | POINT(-73.96085762 40.80085689)
# 138449 | littleleaf linden | Good | Alive | POINT(-73.9607877 40.80237457)
# 113386 | Sophora | Good | Alive | POINT(-73.95473725 40.80835822)
# 121402 | honeylocust | Good | Alive | POINT(-73.96110802 40.80145621)
# 121469 | Schumard's oak | Good | Alive | POINT(-73.96133584 40.8018145)
# 76153 | black locust | Fair | Alive | POINT(-73.96474166 40.81011399)
# 135477 | Sophora | Good | Alive | POINT(-73.95847712 40.81064081)
# 135478 | Sophora | Good | Alive | POINT(-73.95879937 40.81077657)
# 121994 | ginkgo | Fair | Alive | POINT(-73.96414817 40.800598)
# 121992 | ginkgo | Fair | Alive | POINT(-73.96399142 40.80053209)
# 113321 | Sophora | Good | Alive | POINT(-73.95384297 40.80717507)
# 138836 | silver linden | Good | Alive | POINT(-73.95418348 40.81048836)
# 138774 | green ash | Good | Alive | POINT(-73.95383159 40.80952354)
# 21706 | Amur maackia | Fair | Alive | POINT(-73.96294522 40.80583684)
# 138439 | American elm | Good | Alive | POINT(-73.96038679 40.80355368)
# 138769 | green ash | Good | Alive | POINT(-73.95445228 40.80978352)
# 138440 | littleleaf linden | Good | Alive | POINT(-73.96041408 40.80347343)
# 196620 | None | None | Stump | POINT(-73.9679977 40.80593773)
# 138766 | northern red oak | Good | Alive | POINT(-73.95474396 40.80990569)
# 139747 | magnolia | Good | Alive | POINT(-73.95666972 40.80320083)
# 76476 | 'Schubert' chokecherry | Good | Alive | POINT(-73.96758786 40.8055743)
# 139744 | littleleaf linden | Fair | Alive | POINT(-73.95709339 40.8033798)
# 138770 | green ash | Good | Alive | POINT(-73.95432257 40.80972919)
# 142443 | American elm | Good | Alive | POINT(-73.967662 40.80275062)
# 122001 | American hophornbeam | Good | Alive | POINT(-73.96506531 40.80098363)
# 138768 | northern red oak | Good | Alive | POINT(-73.95458198 40.80983785)
# 135291 | None | None | Dead | POINT(-73.95800284 40.80964287)
# 135515 | ginkgo | Good | Alive | POINT(-73.96050193 40.81164168)
# 135438 | pin oak | Good | Alive | POINT(-73.95450135 40.80991611)
# 76475 | 'Schubert' chokecherry | Good | Alive | POINT(-73.96762001 40.80552514)
# 142370 | hawthorn | Good | Alive | POINT(-73.96705119 40.80375939)
# 135517 | ginkgo | Good | Alive | POINT(-73.96025873 40.81153909)
# 135514 | ginkgo | Good | Alive | POINT(-73.96062826 40.81169497)
# 142358 | London planetree | Good | Alive | POINT(-73.96688484 40.80399121)
# 135518 | Chinese elm | Good | Alive | POINT(-73.96015767 40.81149645)
# 135485 | Chinese elm | Good | Alive | POINT(-73.95990512 40.81124242)
# 159231 | ginkgo | Good | Alive | POINT(-73.96532065 40.8007801)
# 135489 | ginkgo | Good | Alive | POINT(-73.96036322 40.81143541)
# 135255 | ginkgo | Good | Alive | POINT(-73.95760191 40.80885793)
# 107031 | Kentucky coffeetree | Good | Alive | POINT(-73.96629364 40.80325785)
# 158881 | honeylocust | Good | Alive | POINT(-73.96479852 40.80148862)
# 135294 | Kentucky coffeetree | Good | Alive | POINT(-73.9583031 40.80976913)
# 158883 | Callery pear | Good | Alive | POINT(-73.96496111 40.80126651)
# 135488 | None | None | Dead | POINT(-73.96029688 40.81140746)
# 121474 | Schumard's oak | Good | Alive | POINT(-73.96204206 40.80210884)
# 159202 | None | None | Dead | POINT(-73.96291852 40.80090477)
# 159208 | London planetree | Good | Alive | POINT(-73.96371067 40.80120809)
# 121988 | London planetree | Good | Alive | POINT(-73.96365137 40.8003891)
# 159211 | London planetree | Fair | Alive | POINT(-73.96414868 40.80139229)
# 159232 | purple-leaf plum | Fair | Alive | POINT(-73.9653769 40.80070338)
# 159204 | London planetree | Good | Alive | POINT(-73.96327897 40.80102655)
# 135287 | sawtooth oak | Good | Alive | POINT(-73.95752558 40.80944218)
# 138403 | Kentucky coffeetree | Good | Alive | POINT(-73.95780446 40.80812788)
# 159210 | London planetree | Good | Alive | POINT(-73.96404187 40.80134737)
# 138621 | green ash | Fair | Alive | POINT(-73.95509235 40.80934777)
# 137965 | willow oak | Good | Alive | POINT(-73.95802806 40.81044267)
# 137972 | American elm | Fair | Alive | POINT(-73.9572 40.80969331)
# 137971 | American elm | Good | Alive | POINT(-73.95721086 40.80989769)
# 135370 | Sophora | Good | Alive | POINT(-73.96062167 40.81085222)
# 135363 | Kentucky coffeetree | Good | Alive | POINT(-73.95909858 40.81021112)
# 135516 | Sophora | Good | Alive | POINT(-73.96041665 40.8116057)
# 135368 | Sophora | Good | Alive | POINT(-73.96043839 40.81077508)
# 138413 | Kentucky coffeetree | Good | Alive | POINT(-73.95887681 40.80663437)
# 158636 | honeylocust | Fair | Alive | POINT(-73.96168928 40.8003794)
# 138421 | Siberian elm | Good | Alive | POINT(-73.95946543 40.80582879)
# 135369 | Kentucky coffeetree | Good | Alive | POINT(-73.96051739 40.81080833)
# 138418 | Siberian elm | Good | Alive | POINT(-73.9591763 40.8062245)
# 138386 | Kentucky coffeetree | Good | Alive | POINT(-73.95793976 40.81054458)
# 138404 | Kentucky coffeetree | Good | Alive | POINT(-73.95785073 40.80803963)
# 135525 | ginkgo | Good | Alive | POINT(-73.95890699 40.81096882)
# 178556 | cherry | Good | Alive | POINT(-73.9566872 40.80787911)
# 178530 | littleleaf linden | Good | Alive | POINT(-73.95842831 40.80298542)
# 178535 | London planetree | Good | Alive | POINT(-73.95831041 40.80429913)
# 159213 | honeylocust | Good | Alive | POINT(-73.96454923 40.80159053)
# 178525 | London planetree | Good | Alive | POINT(-73.95915238 40.80196009)
# 178532 | London planetree | Good | Alive | POINT(-73.95829605 40.80324704)
# 178542 | honeylocust | Good | Alive | POINT(-73.95836085 40.80542985)
# 178538 | honeylocust | Good | Alive | POINT(-73.95834401 40.80487574)
# 178558 | honeylocust | Good | Alive | POINT(-73.95656183 40.808051)
# 178561 | honeylocust | Good | Alive | POINT(-73.95621147 40.80853139)
# 178562 | honeylocust | Good | Alive | POINT(-73.95614038 40.80862886)
# 189182 | honeylocust | Good | Alive | POINT(-73.95875595 40.80831413)
# 189184 | ginkgo | Poor | Alive | POINT(-73.9584516 40.80818611)
# 186774 | pin oak | Good | Alive | POINT(-73.96448135 40.80333069)
# 178545 | London planetree | Good | Alive | POINT(-73.9578771 40.80624756)
# 178546 | London planetree | Good | Alive | POINT(-73.95778991 40.80636712)
# 178555 | London planetree | Good | Alive | POINT(-73.95682692 40.80768753)
# 186773 | pin oak | Fair | Alive | POINT(-73.9643426 40.80327236)
# 186780 | pin oak | Good | Alive | POINT(-73.96511538 40.8035972)
# 188554 | London planetree | Good | Alive | POINT(-73.96067195 40.80320402)
# 188552 | London planetree | Good | Alive | POINT(-73.9607381 40.80301262)
# 135319 | Kentucky coffeetree | Good | Alive | POINT(-73.95842172 40.80992866)
# 186782 | pin oak | Good | Alive | POINT(-73.96537646 40.80370694)
# 193098 | Japanese zelkova | Good | Alive | POINT(-73.96655002 40.80325601)
# 189180 | silver linden | Fair | Alive | POINT(-73.95901478 40.808423)
# 193096 | Callery pear | Good | Alive | POINT(-73.9667315 40.80333276)
# 186775 | Callery pear | Fair | Alive | POINT(-73.96461726 40.80338782)
# 178568 | Callery pear | Good | Alive | POINT(-73.95509291 40.810065)
# 186924 | honeylocust | Good | Alive | POINT(-73.96480466 40.80416411)
# 178567 | Callery pear | Good | Alive | POINT(-73.95524247 40.80985995)
# 178526 | littleleaf linden | Fair | Alive | POINT(-73.95900764 40.80215896)
# 186772 | pin oak | Good | Alive | POINT(-73.96423229 40.80322599)
# 186781 | pin oak | Fair | Alive | POINT(-73.96527911 40.80366602)
# 187105 | ginkgo | Fair | Alive | POINT(-73.95978397 40.80082488)
# 138401 | Kentucky coffeetree | Good | Alive | POINT(-73.95772482 40.80828075)
# 193101 | honeylocust | Good | Alive | POINT(-73.9662325 40.80312175)
# 193102 | honeylocust | Good | Alive | POINT(-73.96609615 40.80306409)
# 187151 | honeylocust | Good | Alive | POINT(-73.96031988 40.80800158)
# 188835 | ginkgo | Good | Alive | POINT(-73.95896487 40.80911741)
# 187152 | honeylocust | Good | Alive | POINT(-73.96010594 40.80829464)
# 187146 | honeylocust | Good | Alive | POINT(-73.96176977 40.8060154)
# 135527 | Sophora | Good | Alive | POINT(-73.95869538 40.81087955)
# 135521 | Sophora | Good | Alive | POINT(-73.95988605 40.81138187)
# 122015 | dawn redwood | Good | Alive | POINT(-73.96287309 40.8001706)
# 178554 | Callery pear | Good | Alive | POINT(-73.95693233 40.80754301)
# 187063 | London planetree | Good | Alive | POINT(-73.96268758 40.80475782)
# 204129 | ginkgo | Poor | Alive | POINT(-73.96227122 40.80496751)
# 204101 | honeylocust | Good | Alive | POINT(-73.96160896 40.80584935)
# 178533 | London planetree | Good | Alive | POINT(-73.9582705 40.80357339)
# 203954 | honeylocust | Good | Alive | POINT(-73.96123775 40.80635473)
# 135439 | black cherry | Good | Alive | POINT(-73.95437498 40.80986288)
# 135437 | black cherry | Good | Alive | POINT(-73.95462773 40.80996933)
# 186776 | Japanese zelkova | Good | Alive | POINT(-73.96474843 40.80344295)
# 189179 | Sophora | Good | Alive | POINT(-73.95909727 40.8084577)
# 187145 | Sophora | Good | Alive | POINT(-73.96182268 40.80594291)
# 178548 | Norway maple | Good | Alive | POINT(-73.95752483 40.80673059)
# 196617 | None | None | Stump | POINT(-73.96778486 40.80634364)
# 203889 | Japanese zelkova | Fair | Alive | POINT(-73.96126539 40.80595424)
# 204079 | Callery pear | Fair | Alive | POINT(-73.96172877 40.80532499)
# 188836 | Callery pear | Fair | Alive | POINT(-73.95882911 40.8090595)
# 188993 | ginkgo | Fair | Alive | POINT(-73.95837521 40.8082646)
# 203955 | ginkgo | Good | Alive | POINT(-73.96131649 40.806253)
# 122006 | sawtooth oak | Fair | Alive | POINT(-73.96443635 40.80082766)
# 204103 | honeylocust | Good | Alive | POINT(-73.96170492 40.80572348)
# 204128 | ginkgo | Poor | Alive | POINT(-73.96219375 40.80507234)
# 203953 | honeylocust | Good | Alive | POINT(-73.96118648 40.80642098)
# 203952 | honeylocust | Good | Alive | POINT(-73.96113814 40.80648344)
# 188992 | ginkgo | Good | Alive | POINT(-73.95827737 40.80822321)
# 198519 | London planetree | Fair | Alive | POINT(-73.96145848 40.8020398)
# 186783 | scarlet oak | Good | Alive | POINT(-73.96550795 40.80376221)
# 198513 | northern red oak | Good | Alive | POINT(-73.96219168 40.80234813)
# 203888 | Japanese zelkova | Fair | Alive | POINT(-73.96115906 40.80590977)
# 196615 | None | None | Stump | POINT(-73.96774289 40.80642429)
# 198508 | pin oak | Good | Alive | POINT(-73.96290465 40.80264795)
# 187144 | pin oak | Good | Alive | POINT(-73.96190643 40.80582818)
# 187102 | pin oak | Fair | Alive | POINT(-73.96246303 40.80506933)
# 203998 | London planetree | Good | Alive | POINT(-73.96055964 40.8049499)
# 187077 | ginkgo | Good | Alive | POINT(-73.96002723 40.80075951)

# %%
# Setting the filename for the SQL query file
QUERY_6_FILENAME = QUERY_DIR / "trees_near_coordinate.sql"
write_query_to_file(QUERY_6, QUERY_6_FILENAME)

# %% [markdown]
# ## Part 4: Visualizing the Data

# %% [markdown]
# ### Visualization 1: What can I expect to put up with in NYC?
# **Question:** First, find the top 3 complaint types for October 1st, 2022 to September 30th, 2023 (inclusive). Then, create an appropriate visualization for the number of complaints per day over $timeframe for those complaint types.
#
# **Solution:**
# - **Objective:** Visualize the daily count of the top 3 complaint types in NYC from October 1st, 2022, to September 30th, 2023.
#
# - **Data Retrieval:** Query: Fetches daily counts of complaints for the three most common types within the specified timeframe.
#
# - **Data Visualization:**
#     - Plot Type: Generates a line plot for each complaint type over the given period.
#     - Visualization Details: The plot shows dates on the x-axis, complaint counts on the y-axis, and includes a legend for each complaint type.
# - **Result:** The resulting plot provides a clear view of the frequency and trends of the top 3 complaint types in NYC over a year, offering insights into common urban issues residents might encounter.

# %%
#Fetches daily counts of complaints for the three most common types 
def get_data_for_complaints()->pd.DataFrame:
    complaints_per_day_query = """
    SELECT 
        created_date::date, 
        complaint_type, 
        COUNT(*) as complaint_count
    FROM 
        nyc_311
    WHERE 
        created_date BETWEEN '2022-10-01' AND '2023-09-30'
        AND complaint_type IN (
            SELECT complaint_type
            FROM nyc_311
            WHERE created_date BETWEEN '2022-10-01' AND '2023-09-30'
            GROUP BY complaint_type
            ORDER BY COUNT(*) DESC
            LIMIT 3
        )
    GROUP BY created_date::date, complaint_type
    ORDER BY created_date
    """

    with engine.connect() as conn:
        complaints_data = pd.read_sql(complaints_per_day_query, conn)

    return complaints_data

# %%
#Generates a line plot for each complaint type over the given period
def plot_complaints(dataframe:pd.DataFrame):
    figure, axes = plt.subplots(figsize=(20, 10))

    # Plotting the data for each complaint type
    for complaint_type in dataframe['complaint_type'].unique():
        filtered_data = dataframe[dataframe['complaint_type'] == complaint_type]
        axes.plot(filtered_data['created_date'], filtered_data['complaint_count'], label=complaint_type)

    # Labeling and styling
    axes.set_title("Top 3 NYC Complaint Types per Day")
    axes.set_xlabel("Date")
    axes.set_ylabel("Number of Complaints")
    axes.legend()

    plt.show()

# %%
# Show the result
complaints_data = get_data_for_complaints()
plot_complaints(complaints_data)

# %% [markdown]
# ### Visualization 2: What are the most common complaints in the immediate area?
# **Question:** Create a visualization that shows the number of complaints by complaint type for the top 10 complaints in zip code 10027 for October 1st, 2018 to September 30th, 2023 (inclusive).
#
# **Solution:**
# - **Objective:** Display the top 10 most common complaints in the zip code 10027 area from October 1st, 2018, to September 30th, 2023.
#
# - **Data Retrieval:**
#     - Query: Extracts data for the top 10 complaint types based on frequency within the specified period for zip code 10027.
#     - Database Interaction: Conducts a SQL query to gather data from the nyc_311 database.
# - **Data Visualization:**
#     - Chart Type: Creates a bar chart to represent the count of each of the top 10 complaints.
#     - Visualization Details: The bar chart displays complaint types on the x-axis and their corresponding counts on the y-axis, with labels rotated for better readability.
# - **Result:** The visualization provides an easy-to-understand representation of the most prevalent complaints in zip code 10027 over a five-year period, highlighting the key issues faced by residents in this area.

# %%
#Extracts data for the top 10 complaint types based on frequency within the specified period for zip code 10027
def get_data_for_most_common_complaints()->pd.DataFrame:
    complaints_query = """
    SELECT 
        complaint_type, 
        COUNT(*) as complaint_count
    FROM 
        nyc_311
    WHERE 
        zipcode = 10027 AND
        created_date BETWEEN '2018-10-01' AND '2023-09-30'
    GROUP BY 
        complaint_type
    ORDER BY 
        complaint_count DESC
    LIMIT 10
    """

    with engine.connect() as conn:
        complaints_data = pd.read_sql(complaints_query, conn)

    return complaints_data

# %%
#Creates a bar chart to represent the count of each of the top 10 complaints
def plot_most_common_complaints(dataframe:pd.DataFrame):
    figure, axes = plt.subplots(figsize=(20, 10))
    # Plotting a bar chart
    axes.bar(dataframe['complaint_type'], dataframe['complaint_count'], color='skyblue')

    # Labeling and styling
    axes.set_title("Top 10 Complaints in Zip Code 10027 (Oct 2018 - Sep 2023)")
    axes.set_xlabel("Complaint Type")
    axes.set_ylabel("Number of Complaints")
    plt.xticks(rotation=45, ha='right')  # Rotate labels for better readability

    plt.show()

# %%
# Show the result
complaints_data_10027 = get_data_for_most_common_complaints()
plot_most_common_complaints(complaints_data_10027)

# %% [markdown]
# ### Visualization 3: Is there any correlation between rent, trees, and complaints at all?
# **Question:** Between January 1st, 2015 and September 30th, 2023 (inclusive), create a visualization using 2 subplots that share the x-axis where one subplot shows rent compared to the number of trees by zip code, and the other subplot shows rent compared to the number of complaints by zip code.
#
# **Solution:**
# - **Objective:** Examine the relationship between average rent, tree count, and complaint count in NYC zip codes from 2015 to 2023.
# - **Data Processing:** Retrieves and merges data on average rent, tree count, and complaint count per zip code.
# - **Visualization:** Creates two scatter plots in one figure, one showing rent vs. tree count and the other showing rent vs. complaint count, with a shared x-axis for average rent.

# %%
def get_data_for_correlation()->pd.DataFrame:
    # Query to get average rent by zip code
    rent_query = """
    SELECT 
         zipcode, 
         AVG(rent) as average_rent
    FROM 
         nyc_zillow
    WHERE 
         recorded_date BETWEEN '2015-01-01' AND '2023-09-30'
    GROUP BY 
         zipcode
    """

    # Query to get tree count by zip code
    tree_query = """
    SELECT 
         zipcode, 
         COUNT(*) as tree_count
    FROM 
         nyc_tree
    WHERE
         status = 'Alive'
    GROUP BY 
         zipcode
    """

    # Query to get complaint count by zip code
    complaint_query = """
    SELECT 
         zipcode, 
         COUNT(*) as complaint_count
    FROM 
         nyc_311
    WHERE 
         created_date BETWEEN '2015-01-01' AND '2023-09-30'
    GROUP BY 
         zipcode
    """

    # Execute queries and return dataframes
    with engine.connect() as conn:
        rent_data = pd.read_sql(rent_query, conn)
        tree_data = pd.read_sql(tree_query, conn)
        complaint_data = pd.read_sql(complaint_query, conn)

    return rent_data, tree_data, complaint_data

# %%
def plot_correlation(rent_df:pd.DataFrame, tree_df:pd.DataFrame, complaint_df:pd.DataFrame):
    # Merging dataframes on zipcode
    merged_df = rent_df.merge(tree_df, on='zipcode').merge(complaint_df, on='zipcode')

    # Creating subplots
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 10), sharex=True)

    # Subplot 1: Rent vs Tree Count
    ax1.scatter(merged_df['average_rent'], merged_df['tree_count'], color='green')
    ax1.set_title('Average Rent vs Tree Count by Zip Code')
    ax1.set_ylabel('Tree Count')

    # Subplot 2: Rent vs Complaint Count
    ax2.scatter(merged_df['average_rent'], merged_df['complaint_count'], color='red')
    ax2.set_title('Average Rent vs Complaint Count by Zip Code')
    ax2.set_xlabel('Average Rent')
    ax2.set_ylabel('Complaint Count')

    plt.show()

# %%
# Show the result
rent_data, tree_data, complaint_data = get_data_for_correlation()
plot_correlation(rent_data, tree_data, complaint_data)

# %% [markdown]
# ### Visualization 4: If I can afford more in rent, will there be fewer issues & complaints?
#
# **Question:** Create a boxplot, where the x-axis is average rent in September 2023, separated into $1000 bins (i.e. $0-1000, $1001-2000, etc), and the y-axis is the number of 311 complaints observed in each zip code between October 1, 2022 (inclusive) to September 30, 2023 (inclusive).
#
# **Solution:**
# - **Objective:** Analyze if higher rent is associated with fewer 311 complaints in NYC from October 2022 to September 2023.
# - **Data Processing:** Gathers average rent for September 2023 and complaint counts over a year, then merges these by zip code.
# - **Visualization:** Creates a boxplot with rent divided into $1000 bins on the x-axis and complaint counts on the y-axis.

# %%
def get_data_for_afford_vs_complaints()->pd.DataFrame:
    # Query to get average rent by zip code for September 2023
    rent_query = """
    SELECT 
         zipcode, 
         AVG(rent) as average_rent
    FROM 
         nyc_zillow
    WHERE 
         recorded_date BETWEEN '2023-09-01' AND '2023-09-30'
    GROUP BY 
         zipcode
    """

    # Query to get complaint count by zip code
    complaint_query = """
    SELECT 
         zipcode, 
         COUNT(*) as complaint_count
    FROM 
         nyc_311
    WHERE 
         created_date BETWEEN '2022-10-01' AND '2023-09-30'
    GROUP BY 
         zipcode
    """

    with engine.connect() as conn:
        rent_data = pd.read_sql(rent_query, conn)
        complaint_data = pd.read_sql(complaint_query, conn)

    # Merging dataframes on zipcode
    merged_data = rent_data.merge(complaint_data, on='zipcode')

    # Categorizing rent into bins
    rent_bins = pd.cut(merged_data['average_rent'], bins=range(0, int(merged_data['average_rent'].max()) + 1000, 1000), right=False)
    merged_data['rent_bins'] = rent_bins

    return merged_data

# %%
def plot_afford_vs_complaints(dataframe:pd.DataFrame):
    fig, ax = plt.subplots(figsize=(20, 10))

    # Creating a boxplot
    dataframe.boxplot(column='complaint_count', by='rent_bins', ax=ax, grid=False)

    # Labeling and styling
    ax.set_title('Number of 311 Complaints vs Average Rent')
    ax.set_xlabel('Average Rent Bins ($)')
    ax.set_ylabel('Number of 311 Complaints')
    plt.suptitle('')  # Remove default Pandas title
    plt.xticks(rotation=45)

    plt.show()

# %%
# Show the result
afford_vs_complaint = get_data_for_afford_vs_complaints()
plot_afford_vs_complaints(afford_vs_complaint)

# %% [markdown]
# ### Visualization 5: Where were the recent 311 incidents reported from in the immediate area?
# **Question:** Create a geospatial plot of the coordinates of reported 311 incidents that happened between January 1st, 2023 and September 30th, 2023 (inclusive) within a 1 kilometer radius of the same coordinate from Query 6 in Part 3.
#
# **Solution:**
# - **Objective:** Map the locations of 311 incidents reported within a 1-kilometer radius of a specific coordinate point (from Query 6) in NYC between January 1st, 2023, and September 30th, 2023.
# - **Data Processing:** Using the `get_data_for_incidents_data()` function, we gather data on the incidents' locations (longitude and latitude) from the NYC 311 database.
# - **Visualization:**
#     - Use `plot_incidents_data(dataframe, point_size=5)` to plot incidents on a map.
#     - Define `create_slider_and_interact(dataframe)` function to create a **slider widget**, allowing users to adjust the size of the incident points on the map.

# %%
def get_data_for_incidents_data()->pd.DataFrame:
    # Modify the query to extract longitude and latitude
    incident_query = f"""
    SELECT 
         ST_X(location::geometry) as longitude, 
         ST_Y(location::geometry) as latitude
    FROM 
         nyc_311
    WHERE 
        created_date BETWEEN '2023-01-01' AND '2023-09-30'
        AND ST_DWithin(location::geography, ST_GeomFromWKB('\\x{point_wkb}', 4326)::geography, 1000)
    """

    with engine.connect() as conn:
        incidents_data = pd.read_sql(incident_query, conn)

    return incidents_data

# %%
def plot_incidents_data(dataframe:pd.DataFrame, point_size=5):
    # Convert DataFrame to GeoDataFrame
    gdf = gpd.GeoDataFrame(dataframe, geometry=gpd.points_from_xy(dataframe['longitude'], dataframe['latitude']))

    # Plotting
    fig, ax = plt.subplots(figsize=(10, 10))
    gdf.plot(ax=ax, markersize=point_size, color='red', marker='o')
    
    # Plot and label the special point (campus)
    plt.scatter(longitude, latitude, color='blue', s=50)  # s is the size of the point
    plt.text(longitude, latitude, ' Campus', verticalalignment='bottom', horizontalalignment='right')

    plt.title("311 Incidents Near Latitude 40.8074, Longitude -73.9625")
    ax.set_xlabel("Longitude")
    ax.set_ylabel("Latitude")    
    
    # Center the plot around the given coordinate
    ax.set_xlim(longitude - 0.015, longitude + 0.015)
    ax.set_ylim(latitude - 0.015, latitude + 0.015)
    
    plt.show()

def create_slider_and_interact(dataframe:pd.DataFrame):
    # Create a slider for adjusting the size of the points on the map
    point_size_slider = IntSlider(min=1, max=10, step=1, value=5, description='Point Size')
    
    # Create an interactive plot with the slider
    interact(plot_incidents_data, dataframe=fixed(dataframe), point_size=point_size_slider)

# %%
# Show the result
incidents_data = get_data_for_incidents_data()
create_slider_and_interact(incidents_data)
# Out:
# interactive(children=(IntSlider(value=5, description='Point Size', max=10, min=1), Output()), _dom_classes=('w…

# %% [markdown]
# ### Visualization 6: Are areas trying to improve the amount of trees in the neighborhood?
#
# **Question:** Create a geospatial plot of two sets of data: the coordinates of trees in NYC, and the coordinates of "New Tree Request" 311 complaint types that were made from October 1st, 2018 to September 30th, 2023 (inclusive).
#
# **Solution:**
#
# - **Objective:** Compare the locations of existing trees and "New Tree Request" complaints in NYC from October 2018 to September 2023.
# - **Data Retrieval:** Gathers coordinates for all existing trees and for "New Tree Request" complaints within the specified timeframe.
# - **Visualization:** Produces a geospatial plot displaying trees as green points and new tree requests as red points.

# %%
def get_data_for_improve_tree()->pd.DataFrame:

    # Query for existing tree coordinates
    tree_query = """
    SELECT 
        tree_id, 
        ST_X(location::geometry) AS longitude, 
        ST_Y(location::geometry) AS latitude
    FROM 
        nyc_tree
    """

    # Query for "New Tree Request" complaint coordinates
    complaint_query = """
    SELECT 
        unique_key, 
        ST_X(location::geometry) AS longitude, 
        ST_Y(location::geometry) AS latitude
    FROM 
        nyc_311
    WHERE 
        complaint_type = 'New Tree Request' AND
        created_date BETWEEN '2018-10-01' AND '2023-09-30'
    """

    # Execute queries and return dataframes
    tree_df = pd.read_sql(tree_query, engine)
    complaint_df = pd.read_sql(complaint_query, engine)

    return tree_df, complaint_df

# %%
def plot_improve_tree(tree_df:pd.DataFrame, complaint_df:pd.DataFrame):
    # Create GeoDataFrames
    tree_gdf = gpd.GeoDataFrame(tree_df, geometry=gpd.points_from_xy(tree_df.longitude, tree_df.latitude))
    complaint_gdf = gpd.GeoDataFrame(complaint_df, geometry=gpd.points_from_xy(complaint_df.longitude, complaint_df.latitude))

    # Plot
    fig, ax = plt.subplots(figsize=(15, 15))
    tree_gdf.plot(ax=ax, marker='o', color='green', markersize=5, label='Existing Trees')
    complaint_gdf.plot(ax=ax, marker='x', color='red', markersize=5, label='New Tree Requests')
    plt.title("NYC Tree Locations vs New Tree Requests (Oct 2018 - Sep 2023)")
    ax.set_xlabel("Longitude")
    ax.set_ylabel("Latitude")
    ax.legend()
    plt.show()

# %%
# Show the result
tree_df, complaint_df = get_data_for_improve_tree()
plot_improve_tree(tree_df, complaint_df)
